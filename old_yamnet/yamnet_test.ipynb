# %%
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_io as tfio
import os, csv

# YAMNet 모델 로드
model = hub.load('https://tfhub.dev/google/yamnet/1')

def load_wav_16k_mono(filename):
    """ 16kHz 모노 WAV 파일 로드 """
    file_contents = tf.io.read_file(filename)
    wav, sample_rate = tf.audio.decode_wav(file_contents, desired_channels=1)
    wav = tf.squeeze(wav, axis=-1)
    sample_rate = tf.cast(sample_rate, dtype=tf.int64)
    wav = tfio.audio.resample(wav, rate_in=sample_rate, rate_out=16000)
    return wav

def get_embedding(wav_data):
    """ YAMNet을 사용하여 오디오 임베딩 생성 """
    scores, embeddings, log_mel_spectrogram = model(wav_data)
    return embeddings

# # 오디오 파일 로드 및 임베딩 생성
# audio_file = 'path_to_your_audio_file.wav'  # 실제 오디오 파일 경로로 변경해야 합니다
# wav_data = load_wav_16k_mono(audio_file)
# embedding = get_embedding(wav_data)
# print(f"Audio embedding shape: {embedding.shape}")
# Out:
# 2024-10-07 06:42:44.933367: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_3' with dtype int32 and shape [?]
# 	 [[{{node inputs_3}}]]
# 2024-10-07 06:42:44.935773: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [3]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:44.935851: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [3]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:44.969453: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [1,2]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:45.011292: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype int32
# 	 [[{{node inputs}}]]
# 2024-10-07 06:42:45.043464: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype int32 and shape [1]
# 	 [[{{node inputs}}]]
# 2024-10-07 06:42:45.043554: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype int32 and shape [1]
# 	 [[{{node inputs}}]]
# 2024-10-07 06:42:45.100603: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype int32
# 	 [[{{node inputs}}]]
# 2024-10-07 06:42:45.105759: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [2]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:45.105850: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [2]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:45.231808: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_3' with dtype int32 and shape [?]
# 	 [[{{node inputs_3}}]]
# 2024-10-07 06:42:45.251546: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [1,2]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:45.273268: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_3' with dtype int32 and shape [?]
# 	 [[{{node inputs_3}}]]
# 2024-10-07 06:42:45.351488: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [2]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:45.351577: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [2]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:45.376466: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [2]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:45.376573: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [2]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:45.395038: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype int32 and shape [1]
# 	 [[{{node inputs}}]]
# 2024-10-07 06:42:45.395126: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype int32 and shape [1]
# 	 [[{{node inputs}}]]
# 2024-10-07 06:42:45.511415: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype int32 and shape [1]
# 	 [[{{node inputs}}]]
# 2024-10-07 06:42:45.511527: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype int32 and shape [1]
# 	 [[{{node inputs}}]]
# 2024-10-07 06:42:45.549311: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [3]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:45.549414: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [3]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:45.892550: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [2]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:45.892649: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [2]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:46.013219: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [2]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:46.013320: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [2]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:46.030694: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [2]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:46.030797: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [2]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:46.130865: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype int32
# 	 [[{{node inputs}}]]
# 2024-10-07 06:42:46.210866: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [3]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:46.210964: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [3]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:46.224597: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [2]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:46.224713: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [2]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:46.476757: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [3]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:46.476847: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [3]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:46.543315: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_3' with dtype int32 and shape [?]
# 	 [[{{node inputs_3}}]]
# 2024-10-07 06:42:46.545279: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype int32
# 	 [[{{node inputs}}]]
# 2024-10-07 06:42:46.551736: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [2]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:46.551811: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs_1' with dtype int32 and shape [2]
# 	 [[{{node inputs_1}}]]
# 2024-10-07 06:42:46.589595: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype int32 and shape [1]
# 	 [[{{node inputs}}]]
# 2024-10-07 06:42:46.589688: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype int32 and shape [1]
# 	 [[{{node inputs}}]]

# %%
from urllib.request import urlopen

# YAMNet 클래스 이름 로드
class_map_path = "https://raw.githubusercontent.com/tensorflow/models/master/research/audioset/yamnet/yamnet_class_map.csv"
class_names = []
with urlopen(class_map_path) as f:
    reader = csv.DictReader(f.read().decode('utf-8').splitlines())
    for row in reader:
        class_names.append(row['display_name'])

# %%
my_classes = [
    "어른발걸음소리",
    "아이들발걸음소리",
    "망치질소리",
    "가구끄는소리",
    "문여닫는소리",
    "런닝머신에서뛰는소리",
    "골프퍼팅(골굴리는소리)",
    "화장실물내리는소리",
    "샤워할때물소리",
    "드럼세탁기소리",
    "통돌이세탁기소리",
    "진공청소기소리",
    "식기세척기소리",
    "바이올린연주소리",
    "피아노연주소리",
    "강아지짓는소리",
    "고양이우는소리"
]

test_dir = '/ai_hub_data/Training/04.balanced_cropped음원'

for cls in my_classes:
    files = os.listdir(os.path.join(test_dir, cls))
    print(f"Class: {cls}")
    counter = 0
    for f in files:
        counter += 1
        audio_file = os.path.join(test_dir, cls, f)
        wav_data = load_wav_16k_mono(audio_file)
        class_scores, embeddings, _ = model(wav_data)
        # 상위 5개 예측 클래스 출력
        top_classes = tf.argsort(class_scores, direction='DESCENDING')[0][:5]
        for i in top_classes:
            print(f"{counter}.{class_names[i]}: {class_scores[0][i]:.3f}")
# Out:
# Class: 어른발걸음소리
# 2024-10-07 06:42:57.100639: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'waveform' with dtype float and shape [?]
# 	 [[{{node waveform}}]]
# 1.Scrape: 0.448
# 1.Tearing: 0.383
# 1.Shuffling cards: 0.361
# 1.Crumpling, crinkling: 0.248
# 1.Scratch: 0.223
# 2.Inside, small room: 0.224
# 2.Speech: 0.152
# 2.Inside, large room or hall: 0.038
# 2.Door: 0.023
# 2.Wood: 0.017
# 3.Hands: 0.542
# 3.Slap, smack: 0.443
# 3.Bouncing: 0.412
# 3.Inside, small room: 0.340
# 3.Door: 0.211
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7f05c8295a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7f05c8295a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4.Inside, small room: 0.378
# 4.Wood: 0.120
# 4.Shuffle: 0.069
# 4.Inside, large room or hall: 0.063
# 4.Zipper (clothing): 0.039
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7f05c8295e50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7f05c8295e50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5.Typewriter: 0.942
# 5.Typing: 0.608
# 5.Rattle (instrument): 0.127
# 5.Inside, small room: 0.088
# 5.Maraca: 0.074
# 6.Cap gun: 0.793
# 6.Gunshot, gunfire: 0.652
# 6.Explosion: 0.442
# 6.Wood: 0.094
# 6.Arrow: 0.048
# 7.Tap: 0.311
# 7.Ping: 0.309
# 7.Door: 0.224
# 7.Shuffle: 0.095
# 7.Inside, large room or hall: 0.069
# 8.Knock: 0.757
# 8.Thunk: 0.635
# 8.Bouncing: 0.548
# 8.Door: 0.418
# 8.Thump, thud: 0.381
# 9.Hands: 0.714
# 9.Finger snapping: 0.685
# 9.Slap, smack: 0.202
# 9.Scratch: 0.121
# 9.Inside, small room: 0.118
# 10.Shuffle: 0.148
# 10.Inside, small room: 0.107
# 10.Hands: 0.068
# 10.Explosion: 0.061
# 10.Cap gun: 0.047
# 11.Inside, small room: 0.451
# 11.Domestic animals, pets: 0.167
# 11.Animal: 0.146
# 11.Dog: 0.120
# 11.Door: 0.112
# 12.Music: 0.876
# 12.Percussion: 0.760
# 12.Drum: 0.699
# 12.Musical instrument: 0.581
# 12.Snare drum: 0.447
# 13.Hands: 0.333
# 13.Whack, thwack: 0.324
# 13.Cap gun: 0.241
# 13.Slap, smack: 0.175
# 13.Wood: 0.122
# 14.Inside, small room: 0.296
# 14.Hands: 0.296
# 14.Ping: 0.195
# 14.Bouncing: 0.177
# 14.Slap, smack: 0.170
# 15.Inside, small room: 0.419
# 15.Hands: 0.083
# 15.Wood block: 0.076
# 15.Percussion: 0.058
# 15.Wood: 0.046
# 16.Inside, small room: 0.280
# 16.Domestic animals, pets: 0.254
# 16.Dog: 0.210
# 16.Animal: 0.164
# 16.Whimper (dog): 0.158
# 17.Chop: 0.632
# 17.Wood: 0.373
# 17.Whack, thwack: 0.324
# 17.Bouncing: 0.246
# 17.Chopping (food): 0.244
# 18.Thunk: 0.192
# 18.Door: 0.185
# 18.Knock: 0.183
# 18.Thump, thud: 0.165
# 18.Sound effect: 0.164
# 19.Tap: 0.395
# 19.Door: 0.371
# 19.Bouncing: 0.282
# 19.Ping: 0.098
# 19.Hands: 0.095
# 20.Silence: 0.402
# 20.Tap: 0.262
# 20.Arrow: 0.257
# 20.Knock: 0.171
# 20.Door: 0.167
# 21.Animal: 0.684
# 21.Dog: 0.625
# 21.Domestic animals, pets: 0.590
# 21.Whimper (dog): 0.220
# 21.Yip: 0.119
# 22.Inside, small room: 0.176
# 22.Clip-clop: 0.113
# 22.Animal: 0.107
# 22.Horse: 0.066
# 22.Livestock, farm animals, working animals: 0.051
# 23.Inside, small room: 0.281
# 23.Inside, large room or hall: 0.093
# 23.Door: 0.063
# 23.Explosion: 0.037
# 23.Percussion: 0.034
# 24.Music: 0.908
# 24.Drum machine: 0.367
# 24.Drum kit: 0.187
# 24.Percussion: 0.120
# 24.Electronic music: 0.119
# 25.Knock: 0.397
# 25.Door: 0.207
# 25.Tap: 0.126
# 25.Whack, thwack: 0.113
# 25.Inside, small room: 0.075
# 26.Inside, small room: 0.069
# 26.Television: 0.048
# 26.Speech: 0.038
# 26.Inside, large room or hall: 0.035
# 26.Music: 0.035
# 27.Shuffle: 0.432
# 27.Inside, small room: 0.121
# 27.Inside, large room or hall: 0.083
# 27.Music: 0.080
# 27.Clip-clop: 0.046
# 28.Crack: 0.776
# 28.Shuffling cards: 0.705
# 28.Crushing: 0.699
# 28.Coin (dropping): 0.483
# 28.Breaking: 0.426
# 29.Inside, small room: 0.482
# 29.Tap: 0.086
# 29.Shuffling cards: 0.045
# 29.Crumpling, crinkling: 0.044
# 29.Door: 0.043
# 30.Tap: 0.303
# 30.Door: 0.293
# 30.Inside, small room: 0.139
# 30.Wood: 0.069
# 30.Drum: 0.059
# 31.Inside, small room: 0.235
# 31.Walk, footsteps: 0.188
# 31.Outside, rural or natural: 0.113
# 31.Animal: 0.080
# 31.Outside, urban or manmade: 0.048
# 32.Inside, small room: 0.324
# 32.Animal: 0.067
# 32.Domestic animals, pets: 0.053
# 32.Inside, large room or hall: 0.045
# 32.Livestock, farm animals, working animals: 0.044
# 33.Music: 0.913
# 33.Electronic music: 0.094
# 33.Techno: 0.084
# 33.Drum machine: 0.047
# 33.Sound effect: 0.028
# 34.Hands: 0.977
# 34.Clapping: 0.830
# 34.Slap, smack: 0.709
# 34.Tap: 0.294
# 34.Door: 0.217
# 35.Door: 0.496
# 35.Tap: 0.284
# 35.Knock: 0.216
# 35.Whack, thwack: 0.102
# 35.Bouncing: 0.094
# 36.Inside, small room: 0.619
# 36.Writing: 0.060
# 36.Speech: 0.026
# 36.Hands: 0.019
# 36.Scissors: 0.016
# 37.Music: 0.474
# 37.Percussion: 0.087
# 37.Tambourine: 0.085
# 37.Musical instrument: 0.055
# 37.Inside, small room: 0.053
# 38.Ping: 0.957
# 38.Clapping: 0.148
# 38.Hands: 0.085
# 38.Inside, small room: 0.063
# 38.Inside, large room or hall: 0.037
# 39.Knock: 0.913
# 39.Whack, thwack: 0.583
# 39.Door: 0.575
# 39.Thunk: 0.545
# 39.Chop: 0.539
# 40.Door: 0.935
# 40.Tap: 0.905
# 40.Hands: 0.077
# 40.Clapping: 0.017
# 40.Inside, small room: 0.009
# 41.Whack, thwack: 0.275
# 41.Door: 0.229
# 41.Knock: 0.228
# 41.Hands: 0.178
# 41.Tap: 0.146
# 42.Clapping: 0.862
# 42.Hands: 0.842
# 42.Ping: 0.347
# 42.Inside, small room: 0.054
# 42.Door: 0.033
# 43.Crack: 0.167
# 43.Inside, small room: 0.150
# 43.Whack, thwack: 0.125
# 43.Wood: 0.120
# 43.Chopping (food): 0.105
# 44.Chopping (food): 0.833
# 44.Wood: 0.460
# 44.Whack, thwack: 0.451
# 44.Chop: 0.354
# 44.Cap gun: 0.243
# 45.Scratch: 0.232
# 45.Shuffling cards: 0.179
# 45.Crumpling, crinkling: 0.171
# 45.Crack: 0.152
# 45.Tearing: 0.147
# 46.Music: 0.271
# 46.Sound effect: 0.126
# 46.Drum machine: 0.107
# 46.Tap: 0.089
# 46.Door: 0.077
# 47.Bouncing: 0.702
# 47.Door: 0.410
# 47.Tap: 0.370
# 47.Knock: 0.238
# 47.Hands: 0.219
# 48.Crackle: 0.622
# 48.Crumpling, crinkling: 0.525
# 48.Fire: 0.458
# 48.Inside, small room: 0.195
# 48.Tearing: 0.164
# 49.Tearing: 0.521
# 49.Crunch: 0.414
# 49.Crumpling, crinkling: 0.296
# 49.Inside, small room: 0.291
# 49.Scratch: 0.282
# 50.Hands: 0.656
# 50.Slap, smack: 0.617
# 50.Chopping (food): 0.416
# 50.Whack, thwack: 0.232
# 50.Whip: 0.158
# 51.Whip: 0.741
# 51.Hands: 0.468
# 51.Slap, smack: 0.399
# 51.Clapping: 0.201
# 51.Explosion: 0.181
# 52.Chop: 0.543
# 52.Wood: 0.519
# 52.Chopping (food): 0.444
# 52.Whack, thwack: 0.227
# 52.Tools: 0.191
# 53.Music: 0.575
# 53.Percussion: 0.329
# 53.Wood block: 0.229
# 53.Musical instrument: 0.176
# 53.Drum: 0.080
# 54.Knock: 0.956
# 54.Bouncing: 0.608
# 54.Door: 0.587
# 54.Tap: 0.192
# 54.Thunk: 0.073
# 55.Music: 0.989
# 55.Electronic music: 0.060
# 55.House music: 0.057
# 55.Techno: 0.052
# 55.Drum machine: 0.029
# 56.Knock: 0.389
# 56.Thunk: 0.364
# 56.Door: 0.323
# 56.Bouncing: 0.294
# 56.Thump, thud: 0.286
# 57.Inside, small room: 0.209
# 57.Percussion: 0.118
# 57.Musical instrument: 0.057
# 57.Drum machine: 0.056
# 57.Drum: 0.049
# 58.Tap: 0.682
# 58.Door: 0.673
# 58.Arrow: 0.138
# 58.Hands: 0.076
# 58.Whip: 0.064
# 59.Sliding door: 0.271
# 59.Inside, small room: 0.219
# 59.Door: 0.136
# 59.Drawer open or close: 0.091
# 59.Inside, large room or hall: 0.086
# 60.Bouncing: 0.359
# 60.Shuffle: 0.179
# 60.Ping: 0.174
# 60.Wood: 0.171
# 60.Inside, small room: 0.153
# 61.Crack: 0.248
# 61.Shuffling cards: 0.221
# 61.Hands: 0.209
# 61.Slap, smack: 0.147
# 61.Inside, small room: 0.143
# 62.Typing: 0.306
# 62.Computer keyboard: 0.261
# 62.Sound effect: 0.205
# 62.Glass: 0.097
# 62.Keys jangling: 0.071
# 63.Music: 0.595
# 63.Drum machine: 0.077
# 63.Drum kit: 0.052
# 63.Sampler: 0.047
# 63.Synthesizer: 0.047
# 64.Bouncing: 0.620
# 64.Knock: 0.410
# 64.Inside, small room: 0.227
# 64.Door: 0.134
# 64.Hands: 0.096
# 65.Rattle: 0.225
# 65.Keys jangling: 0.209
# 65.Coin (dropping): 0.188
# 65.Snake: 0.177
# 65.Typing: 0.170
# 66.Inside, small room: 0.333
# 66.Wood: 0.063
# 66.Percussion: 0.054
# 66.Musical instrument: 0.045
# 66.Drum: 0.040
# 67.Bouncing: 0.570
# 67.Hands: 0.513
# 67.Knock: 0.309
# 67.Door: 0.238
# 67.Tap: 0.229
# 68.Beatboxing: 0.203
# 68.Inside, small room: 0.146
# 68.Breathing: 0.109
# 68.Domestic animals, pets: 0.100
# 68.Dog: 0.088
# 69.Door: 0.267
# 69.Inside, small room: 0.249
# 69.Tap: 0.222
# 69.Knock: 0.167
# 69.Computer keyboard: 0.146
# 70.Knock: 0.934
# 70.Door: 0.479
# 70.Bouncing: 0.419
# 70.Whack, thwack: 0.161
# 70.Tap: 0.143
# 71.Knock: 0.412
# 71.Inside, small room: 0.248
# 71.Wood: 0.145
# 71.Door: 0.144
# 71.Whack, thwack: 0.139
# 72.Inside, small room: 0.584
# 72.Scissors: 0.190
# 72.Hands: 0.048
# 72.Silence: 0.041
# 72.Shuffling cards: 0.036
# 73.Inside, small room: 0.537
# 73.Typewriter: 0.225
# 73.Crumpling, crinkling: 0.222
# 73.Shuffling cards: 0.195
# 73.Typing: 0.165
# 74.Knock: 0.921
# 74.Thunk: 0.741
# 74.Door: 0.712
# 74.Bouncing: 0.636
# 74.Tap: 0.433
# 75.Basketball bounce: 0.605
# 75.Arrow: 0.348
# 75.Trickle, dribble: 0.304
# 75.Pour: 0.249
# 75.Thump, thud: 0.229
# 76.Bouncing: 0.671
# 76.Hands: 0.561
# 76.Slap, smack: 0.535
# 76.Door: 0.397
# 76.Knock: 0.285
# 77.Knock: 0.502
# 77.Door: 0.188
# 77.Inside, small room: 0.167
# 77.Tap: 0.116
# 77.Wood block: 0.094
# 78.Inside, small room: 0.596
# 78.Domestic animals, pets: 0.057
# 78.Dog: 0.038
# 78.Animal: 0.032
# 78.Inside, large room or hall: 0.022
# 79.Inside, small room: 0.510
# 79.Wood: 0.040
# 79.Wood block: 0.029
# 79.Inside, large room or hall: 0.028
# 79.Hands: 0.028
# 80.Inside, small room: 0.415
# 80.Wood: 0.080
# 80.Writing: 0.073
# 80.Rub: 0.063
# 80.Scratch: 0.042
# 81.Inside, small room: 0.416
# 81.Writing: 0.178
# 81.Pant: 0.108
# 81.Breathing: 0.074
# 81.Domestic animals, pets: 0.072
# 82.Thump, thud: 0.182
# 82.Arrow: 0.168
# 82.Thunk: 0.164
# 82.Knock: 0.162
# 82.Door: 0.158
# 83.Inside, small room: 0.207
# 83.Clip-clop: 0.151
# 83.Animal: 0.100
# 83.Horse: 0.095
# 83.Tap: 0.089
# 84.Percussion: 0.192
# 84.Wood block: 0.191
# 84.Musical instrument: 0.152
# 84.Music: 0.132
# 84.Drum: 0.070
# 85.Whack, thwack: 0.186
# 85.Percussion: 0.160
# 85.Wood: 0.158
# 85.Door: 0.142
# 85.Drum: 0.120
# 86.Clapping: 0.296
# 86.Hands: 0.203
# 86.Tap: 0.195
# 86.Inside, large room or hall: 0.158
# 86.Door: 0.149
# 87.Music: 0.421
# 87.Percussion: 0.225
# 87.Drum kit: 0.167
# 87.Drum: 0.154
# 87.Musical instrument: 0.153
# 88.Tap: 0.567
# 88.Door: 0.522
# 88.Thump, thud: 0.259
# 88.Arrow: 0.154
# 88.Run: 0.114
# 89.Inside, small room: 0.308
# 89.Rail transport: 0.181
# 89.Inside, large room or hall: 0.171
# 89.Train: 0.166
# 89.Vehicle: 0.133
# 90.Walk, footsteps: 0.476
# 90.Inside, small room: 0.239
# 90.Animal: 0.141
# 90.Door: 0.138
# 90.Insect: 0.099
# 91.Music: 0.502
# 91.Percussion: 0.388
# 91.Drum: 0.286
# 91.Musical instrument: 0.279
# 91.Wood block: 0.194
# 92.Slap, smack: 0.767
# 92.Breaking: 0.609
# 92.Hands: 0.597
# 92.Whip: 0.397
# 92.Cap gun: 0.346
# 93.Inside, small room: 0.385
# 93.Bouncing: 0.158
# 93.Hands: 0.131
# 93.Dishes, pots, and pans: 0.103
# 93.Chopping (food): 0.063
# 94.Inside, small room: 0.274
# 94.Inside, large room or hall: 0.098
# 94.Walk, footsteps: 0.062
# 94.Animal: 0.047
# 94.Speech: 0.038
# 95.Inside, small room: 0.224
# 95.Shuffle: 0.109
# 95.Domestic animals, pets: 0.067
# 95.Dog: 0.059
# 95.Inside, large room or hall: 0.051
# 96.Inside, small room: 0.496
# 96.Inside, large room or hall: 0.061
# 96.Speech: 0.034
# 96.Dishes, pots, and pans: 0.028
# 96.Domestic animals, pets: 0.020
# 97.Chopping (food): 0.786
# 97.Hands: 0.545
# 97.Slap, smack: 0.431
# 97.Whack, thwack: 0.347
# 97.Wood: 0.178
# 98.Chopping (food): 0.457
# 98.Shuffling cards: 0.447
# 98.Coin (dropping): 0.180
# 98.Inside, small room: 0.144
# 98.Hands: 0.126
# 99.Knock: 0.742
# 99.Door: 0.347
# 99.Bouncing: 0.156
# 99.Tap: 0.154
# 99.Whack, thwack: 0.123
# 100.Inside, small room: 0.399
# 100.Hands: 0.072
# 100.Percussion: 0.055
# 100.Wood: 0.037
# 100.Slap, smack: 0.037
# 101.Inside, small room: 0.258
# 101.Shuffle: 0.255
# 101.Breathing: 0.136
# 101.Snort: 0.113
# 101.Hands: 0.094
# 102.Whip: 0.347
# 102.Crackle: 0.343
# 102.Fire: 0.298
# 102.Firecracker: 0.197
# 102.Explosion: 0.158
# 103.Inside, small room: 0.592
# 103.Inside, large room or hall: 0.045
# 103.Dishes, pots, and pans: 0.041
# 103.Tools: 0.015
# 103.Domestic animals, pets: 0.014
# 104.Scissors: 0.574
# 104.Inside, small room: 0.556
# 104.Tearing: 0.408
# 104.Shuffling cards: 0.379
# 104.Crumpling, crinkling: 0.140
# 105.Inside, small room: 0.491
# 105.Door: 0.136
# 105.Wood: 0.096
# 105.Mechanisms: 0.075
# 105.Mechanical fan: 0.068
# 106.Chop: 0.472
# 106.Wood: 0.461
# 106.Whack, thwack: 0.377
# 106.Thump, thud: 0.280
# 106.Arrow: 0.273
# 107.Music: 0.974
# 107.Percussion: 0.458
# 107.Drum kit: 0.324
# 107.Drum machine: 0.245
# 107.Musical instrument: 0.214
# 108.Drum: 0.253
# 108.Percussion: 0.242
# 108.Music: 0.154
# 108.Musical instrument: 0.147
# 108.Snare drum: 0.125
# 109.Knock: 0.759
# 109.Thunk: 0.738
# 109.Whack, thwack: 0.455
# 109.Door: 0.407
# 109.Thump, thud: 0.387
# 110.Crumpling, crinkling: 0.289
# 110.Inside, small room: 0.205
# 110.Snake: 0.145
# 110.Clip-clop: 0.138
# 110.Fire: 0.137
# 111.Percussion: 0.163
# 111.Inside, small room: 0.145
# 111.Drum: 0.116
# 111.Wood: 0.098
# 111.Musical instrument: 0.082
# 112.Bouncing: 0.601
# 112.Inside, small room: 0.361
# 112.Tap: 0.088
# 112.Door: 0.074
# 112.Wood: 0.072
# 113.Clip-clop: 0.649
# 113.Horse: 0.587
# 113.Animal: 0.445
# 113.Livestock, farm animals, working animals: 0.247
# 113.Inside, small room: 0.230
# 114.Ping: 0.884
# 114.Tap: 0.113
# 114.Inside, small room: 0.098
# 114.Wood block: 0.062
# 114.Door: 0.053
# 115.Door: 0.622
# 115.Tap: 0.493
# 115.Bouncing: 0.227
# 115.Hands: 0.223
# 115.Arrow: 0.211
# 116.Door: 0.524
# 116.Tap: 0.411
# 116.Bouncing: 0.377
# 116.Hands: 0.296
# 116.Shuffle: 0.212
# 117.Bouncing: 0.290
# 117.Door: 0.277
# 117.Inside, small room: 0.142
# 117.Hands: 0.103
# 117.Tap: 0.101
# 118.Hands: 0.765
# 118.Clapping: 0.665
# 118.Tap: 0.313
# 118.Door: 0.281
# 118.Ping: 0.068
# 119.Cap gun: 0.672
# 119.Gunshot, gunfire: 0.353
# 119.Explosion: 0.251
# 119.Arrow: 0.182
# 119.Inside, small room: 0.088
# 120.Inside, small room: 0.340
# 120.Animal: 0.183
# 120.Clip-clop: 0.164
# 120.Domestic animals, pets: 0.151
# 120.Dog: 0.141
# 121.Inside, small room: 0.199
# 121.Ping: 0.134
# 121.Hands: 0.134
# 121.Clapping: 0.111
# 121.Slap, smack: 0.070
# 122.Tap: 0.429
# 122.Hands: 0.366
# 122.Shuffle: 0.252
# 122.Door: 0.225
# 122.Clapping: 0.198
# 123.Arrow: 0.662
# 123.Thump, thud: 0.634
# 123.Tap: 0.152
# 123.Door: 0.108
# 123.Inside, large room or hall: 0.079
# 124.Music: 0.770
# 124.Drum: 0.374
# 124.Percussion: 0.365
# 124.Drum kit: 0.270
# 124.Bass drum: 0.224
# 125.Whip: 0.533
# 125.Cap gun: 0.438
# 125.Gunshot, gunfire: 0.244
# 125.Hands: 0.228
# 125.Slap, smack: 0.197
# 126.Knock: 0.247
# 126.Thunk: 0.244
# 126.Whack, thwack: 0.191
# 126.Thump, thud: 0.184
# 126.Door: 0.140
# 127.Percussion: 0.155
# 127.Music: 0.132
# 127.Wood block: 0.099
# 127.Inside, small room: 0.098
# 127.Drum: 0.087
# 128.Heart sounds, heartbeat: 0.152
# 128.Throbbing: 0.093
# 128.Drum: 0.089
# 128.Hum: 0.066
# 128.Inside, small room: 0.058
# 129.Bouncing: 0.233
# 129.Inside, small room: 0.163
# 129.Wood block: 0.091
# 129.Door: 0.091
# 129.Percussion: 0.065
# 130.Horse: 0.350
# 130.Clip-clop: 0.294
# 130.Livestock, farm animals, working animals: 0.183
# 130.Animal: 0.123
# 130.Tap: 0.105
# 131.Bouncing: 0.256
# 131.Inside, small room: 0.191
# 131.Shuffle: 0.131
# 131.Pant: 0.126
# 131.Clip-clop: 0.117
# 132.Inside, small room: 0.321
# 132.Bouncing: 0.155
# 132.Ping: 0.096
# 132.Wood: 0.055
# 132.Hands: 0.055
# 133.Rattle (instrument): 0.600
# 133.Maraca: 0.463
# 133.Music: 0.302
# 133.Percussion: 0.282
# 133.Musical instrument: 0.226
# 134.Inside, small room: 0.231
# 134.Tap: 0.049
# 134.Percussion: 0.046
# 134.Door: 0.044
# 134.Wood block: 0.040
# 135.Cap gun: 0.821
# 135.Gunshot, gunfire: 0.598
# 135.Explosion: 0.386
# 135.Inside, small room: 0.161
# 135.Hands: 0.048
# 136.Inside, small room: 0.159
# 136.Percussion: 0.140
# 136.Drum: 0.090
# 136.Wood block: 0.055
# 136.Musical instrument: 0.048
# 137.Wood: 0.357
# 137.Whack, thwack: 0.352
# 137.Chop: 0.230
# 137.Door: 0.189
# 137.Ping: 0.133
# 138.Knock: 0.468
# 138.Thunk: 0.422
# 138.Crack: 0.403
# 138.Door: 0.216
# 138.Breaking: 0.201
# 139.Door: 0.607
# 139.Tap: 0.565
# 139.Walk, footsteps: 0.196
# 139.Run: 0.194
# 139.Thump, thud: 0.107
# 140.Wood: 0.457
# 140.Inside, small room: 0.307
# 140.Rub: 0.298
# 140.Tools: 0.274
# 140.Chopping (food): 0.183
# 141.Percussion: 0.312
# 141.Drum machine: 0.234
# 141.Drum kit: 0.185
# 141.Musical instrument: 0.176
# 141.Inside, small room: 0.131
# 142.Clapping: 0.830
# 142.Hands: 0.815
# 142.Tap: 0.090
# 142.Inside, small room: 0.064
# 142.Ping: 0.063
# 143.Thump, thud: 0.489
# 143.Arrow: 0.418
# 143.Door: 0.320
# 143.Tap: 0.282
# 143.Inside, large room or hall: 0.164
# 144.Walk, footsteps: 0.321
# 144.Crackle: 0.258
# 144.Fire: 0.212
# 144.Outside, rural or natural: 0.179
# 144.Snake: 0.100
# 145.Music: 0.818
# 145.Percussion: 0.629
# 145.Musical instrument: 0.541
# 145.Drum: 0.397
# 166.Goat: 0.044
# 167.Inside, small room: 0.365
# 167.Inside, large room or hall: 0.036
# 167.Speech: 0.027
# 167.Shuffle: 0.023
# 167.Door: 0.022
# 168.Knock: 0.788
# 168.Thunk: 0.602
# 168.Thump, thud: 0.465
# 168.Walk, footsteps: 0.373
# 168.Door: 0.339
# 169.Knock: 0.905
# 169.Thunk: 0.718
# 169.Door: 0.448
# 169.Thump, thud: 0.354
# 169.Bouncing: 0.162
# 170.Knock: 0.797
# 170.Thunk: 0.486
# 170.Door: 0.322
# 170.Thump, thud: 0.313
# 170.Whack, thwack: 0.226
# 171.Cap gun: 0.848
# 171.Gunshot, gunfire: 0.640
# 171.Explosion: 0.504
# 171.Inside, small room: 0.211
# 171.Hands: 0.173
# 172.Slap, smack: 0.703
# 172.Crack: 0.678
# 172.Hands: 0.600
# 172.Bouncing: 0.383
# 172.Knock: 0.358
# 173.Inside, small room: 0.501
# 173.Scissors: 0.113
# 173.Writing: 0.074
# 173.Silence: 0.052
# 173.Hands: 0.038
# 174.Cap gun: 0.724
# 174.Gunshot, gunfire: 0.514
# 174.Explosion: 0.426
# 174.Wood: 0.207
# 174.Whack, thwack: 0.135
# 175.Scratch: 0.544
# 175.Scrape: 0.123
# 175.Crack: 0.122
# 175.Zipper (clothing): 0.100
# 175.Whack, thwack: 0.095
# 176.Wood: 0.375
# 176.Chopping (food): 0.190
# 176.Cap gun: 0.180
# 176.Hands: 0.166
# 176.Slap, smack: 0.155
# 177.Music: 0.424
# 177.Musical instrument: 0.124
# 177.Percussion: 0.102
# 177.Shuffle: 0.085
# 177.Inside, small room: 0.076
# 178.Hands: 0.311
# 178.Door: 0.311
# 178.Tap: 0.278
# 178.Clapping: 0.209
# 178.Slap, smack: 0.125
# 179.Crack: 0.230
# 179.Sound effect: 0.153
# 179.Wood: 0.126
# 179.Arrow: 0.120
# 179.Door: 0.112
# 180.Chopping (food): 0.909
# 180.Chop: 0.827
# 180.Wood: 0.589
# 180.Whack, thwack: 0.373
# 180.Cap gun: 0.131
# 181.Music: 0.918
# 181.Drum: 0.062
# 181.Percussion: 0.054
# 181.Musical instrument: 0.040
# 181.Wood block: 0.028
# 182.Inside, large room or hall: 0.185
# 182.Door: 0.173
# 182.Inside, small room: 0.099
# 182.Tap: 0.078
# 182.Bathtub (filling or washing): 0.069
# 183.Inside, small room: 0.257
# 183.Walk, footsteps: 0.223
# 183.Inside, large room or hall: 0.096
# 183.Shuffle: 0.085
# 183.Clip-clop: 0.072
# 184.Inside, small room: 0.344
# 184.Silence: 0.302
# 184.Writing: 0.133
# 184.Printer: 0.024
# 184.Wood: 0.024
# 185.Scissors: 0.624
# 185.Shuffling cards: 0.459
# 185.Inside, small room: 0.381
# 185.Coin (dropping): 0.317
# 185.Scratch: 0.122
# 186.Wood: 0.365
# 186.Knock: 0.232
# 186.Chop: 0.229
# 186.Inside, small room: 0.206
# 186.Whack, thwack: 0.150
# 187.Horse: 0.226
# 187.Clip-clop: 0.213
# 187.Door: 0.166
# 187.Tap: 0.128
# 187.Livestock, farm animals, working animals: 0.121
# 188.Slap, smack: 0.710
# 188.Hands: 0.608
# 188.Bouncing: 0.438
# 188.Door: 0.322
# 188.Arrow: 0.248
# 189.Door: 0.907
# 189.Tap: 0.896
# 189.Hands: 0.283
# 189.Clapping: 0.090
# 189.Slap, smack: 0.016
# 190.Music: 0.939
# 190.Drum machine: 0.059
# 190.Scratching (performance technique): 0.038
# 190.Sampler: 0.034
# 190.Drum kit: 0.030
# 191.Door: 0.233
# 191.Tap: 0.188
# 191.Inside, large room or hall: 0.130
# 191.Arrow: 0.049
# 191.Fire: 0.044
# 192.Percussion: 0.482
# 192.Music: 0.457
# 192.Wood block: 0.370
# 192.Musical instrument: 0.329
# 192.Drum: 0.184
# 193.Domestic animals, pets: 0.280
# 193.Dog: 0.268
# 193.Inside, small room: 0.202
# 193.Animal: 0.176
# 193.Whimper (dog): 0.041
# 194.Thump, thud: 0.348
# 194.Arrow: 0.320
# 194.Applause: 0.298
# 194.Tap: 0.168
# 194.Inside, large room or hall: 0.151
# 195.Inside, small room: 0.439
# 195.Shuffling cards: 0.339
# 195.Scratch: 0.331
# 195.Typing: 0.273
# 195.Scissors: 0.237
# 196.Music: 0.474
# 196.Musical instrument: 0.140
# 196.Percussion: 0.137
# 196.Inside, small room: 0.064
# 196.Drum: 0.056
# 197.Tap: 0.974
# 197.Door: 0.937
# 197.Inside, large room or hall: 0.018
# 197.Thump, thud: 0.017
# 197.Arrow: 0.013
# 198.Percussion: 0.209
# 198.Music: 0.203
# 198.Knock: 0.191
# 198.Wood block: 0.157
# 198.Musical instrument: 0.155
# 199.Hands: 0.925
# 199.Clapping: 0.871
# 199.Door: 0.189
# 199.Tap: 0.157
# 199.Slap, smack: 0.043
# 200.Typing: 0.242
# 200.Inside, small room: 0.240
# 200.Computer keyboard: 0.225
# 200.Percussion: 0.036
# 200.Speech: 0.036
# 201.Music: 0.846
# 201.Drum machine: 0.225
# 201.Percussion: 0.142
# 201.Musical instrument: 0.117
# 201.Drum kit: 0.102
# 202.Bouncing: 0.492
# 202.Inside, small room: 0.324
# 202.Knock: 0.218
# 202.Door: 0.127
# 202.Tap: 0.101
# 203.Breaking: 0.243
# 203.Crack: 0.213
# 203.Inside, small room: 0.092
# 203.Crackle: 0.087
# 203.Fire: 0.064
# 204.Bouncing: 0.307
# 204.Thunk: 0.280
# 204.Knock: 0.259
# 204.Door: 0.245
# 204.Wood block: 0.182
# 205.Inside, small room: 0.200
# 205.Percussion: 0.134
# 205.Music: 0.098
# 205.Musical instrument: 0.090
# 205.Wood block: 0.084
# 206.Scratch: 0.427
# 206.Scratching (performance technique): 0.299
# 206.Whack, thwack: 0.195
# 206.Musical instrument: 0.147
# 206.Sound effect: 0.132
# 207.Inside, small room: 0.516
# 207.Bouncing: 0.076
# 207.Domestic animals, pets: 0.044
# 207.Hands: 0.043
# 207.Dog: 0.034
# 208.Sound effect: 0.099
# 208.Music: 0.096
# 208.Percussion: 0.078
# 208.Wood block: 0.065
# 208.Ping: 0.065
# 209.Crack: 0.742
# 209.Knock: 0.404
# 209.Thunk: 0.337
# 209.Door: 0.223
# 209.Thump, thud: 0.218
# 210.Knock: 0.600
# 210.Bouncing: 0.562
# 210.Thunk: 0.476
# 210.Walk, footsteps: 0.322
# 210.Door: 0.314
# 211.Inside, small room: 0.505
# 211.Shuffling cards: 0.079
# 211.Writing: 0.065
# 211.Scissors: 0.045
# 211.Zipper (clothing): 0.035
# 212.Knock: 0.855
# 212.Door: 0.477
# 212.Thunk: 0.289
# 212.Whack, thwack: 0.232
# 212.Thump, thud: 0.203
# 213.Music: 0.789
# 213.Musical instrument: 0.072
# 213.Percussion: 0.056
# 213.Drum kit: 0.045
# 213.Drum: 0.037
# 214.Crack: 0.972
# 214.Crushing: 0.876
# 214.Crunch: 0.733
# 214.Breaking: 0.729
# 214.Shuffling cards: 0.706
# 215.Drum machine: 0.214
# 215.Percussion: 0.148
# 215.Knock: 0.142
# 215.Musical instrument: 0.107
# 215.Music: 0.102
# 216.Door: 0.210
# 216.Thump, thud: 0.150
# 216.Sound effect: 0.150
# 216.Tap: 0.120
# 216.Whack, thwack: 0.093
# 217.Ping: 0.212
# 217.Hands: 0.208
# 217.Wood block: 0.193
# 217.Bouncing: 0.106
# 217.Percussion: 0.105
# 218.Computer keyboard: 0.334
# 218.Typing: 0.317
# 218.Tap: 0.141
# 218.Drum machine: 0.131
# 218.Inside, small room: 0.121
# 219.Inside, small room: 0.518
# 219.Domestic animals, pets: 0.080
# 219.Dog: 0.056
# 219.Inside, large room or hall: 0.047
# 219.Animal: 0.038
# 220.Music: 0.887
# 220.Electronic music: 0.041
# 220.Electronic dance music: 0.031
# 220.House music: 0.026
# 220.Drum machine: 0.017
# 221.Music: 0.847
# 221.Drum machine: 0.333
# 221.Percussion: 0.259
# 221.Drum kit: 0.259
# 221.Musical instrument: 0.146
# 222.Door: 0.463
# 222.Tap: 0.295
# 222.Arrow: 0.246
# 222.Whack, thwack: 0.231
# 222.Hands: 0.137
# 223.Snake: 0.221
# 223.Bicycle: 0.199
# 223.Rail transport: 0.198
# 223.Train: 0.195
# 223.Rattle: 0.174
# 224.Heart sounds, heartbeat: 0.992
# 224.Heart murmur: 0.656
# 224.Throbbing: 0.471
# 224.Hum: 0.317
# 224.Noise: 0.190
# 225.Door: 0.351
# 225.Tap: 0.343
# 225.Walk, footsteps: 0.334
# 225.Clip-clop: 0.299
# 225.Horse: 0.267
# 226.Bouncing: 0.738
# 226.Knock: 0.440
# 226.Door: 0.414
# 226.Thunk: 0.363
# 226.Slam: 0.352
# 227.Rub: 0.361
# 227.Wood: 0.233
# 227.Sawing: 0.225
# 227.Tools: 0.218
# 227.Inside, small room: 0.151
# 228.Inside, small room: 0.678
# 228.Inside, large room or hall: 0.054
# 228.Door: 0.019
# 228.Domestic animals, pets: 0.011
# 228.Animal: 0.009
# 229.Clip-clop: 0.241
# 229.Typing: 0.197
# 229.Music: 0.166
# 229.Computer keyboard: 0.142
# 229.Horse: 0.116
# 230.Crack: 0.743
# 230.Breaking: 0.406
# 230.Knock: 0.353
# 251.Crushing: 0.751
# 251.Breaking: 0.681
# 251.Crunch: 0.570
# 251.Tearing: 0.449
# 252.Silence: 0.558
# 252.Inside, small room: 0.212
# 252.Writing: 0.040
# 252.Walk, footsteps: 0.030
# 252.Domestic animals, pets: 0.026
# 253.Speech: 0.419
# 253.Inside, small room: 0.077
# 253.Tap: 0.061
# 253.Door: 0.037
# 253.Hands: 0.028
# 254.Door: 0.960
# 254.Tap: 0.946
# 254.Hands: 0.158
# 254.Clapping: 0.107
# 254.Arrow: 0.005
# 255.Rattle (instrument): 0.811
# 255.Percussion: 0.697
# 255.Maraca: 0.659
# 255.Tambourine: 0.475
# 255.Musical instrument: 0.444
# 256.Bouncing: 0.492
# 256.Knock: 0.379
# 256.Door: 0.271
# 256.Inside, small room: 0.241
# 256.Hands: 0.237
# 257.Shuffling cards: 0.902
# 257.Coin (dropping): 0.525
# 257.Scissors: 0.444
# 257.Inside, small room: 0.389
# 257.Typewriter: 0.124
# 258.Wood block: 0.374
# 258.Percussion: 0.253
# 258.Musical instrument: 0.210
# 258.Drum: 0.142
# 258.Music: 0.090
# 259.Whack, thwack: 0.631
# 259.Whoosh, swoosh, swish: 0.333
# 259.Sound effect: 0.274
# 259.Arrow: 0.259
# 259.Thump, thud: 0.132
# 260.Chopping (food): 0.893
# 260.Whack, thwack: 0.467
# 260.Cap gun: 0.464
# 260.Slap, smack: 0.368
# 260.Gunshot, gunfire: 0.336
# 261.Knock: 0.520
# 261.Door: 0.212
# 261.Bouncing: 0.201
# 261.Percussion: 0.123
# 261.Inside, small room: 0.115
# 262.Door: 0.578
# 262.Tap: 0.169
# 262.Whip: 0.155
# 262.Knock: 0.137
# 262.Hands: 0.109
# 263.Tap: 0.132
# 263.Inside, small room: 0.126
# 263.Percussion: 0.085
# 263.Shuffle: 0.072
# 263.Wood block: 0.069
# 264.Hands: 0.321
# 264.Inside, small room: 0.307
# 264.Chopping (food): 0.252
# 264.Slap, smack: 0.131
# 264.Scratch: 0.109
# 265.Inside, small room: 0.224
# 265.Shuffling cards: 0.172
# 265.Zipper (clothing): 0.126
# 265.Crackle: 0.114
# 265.Scrape: 0.091
# 266.Tap: 0.925
# 266.Door: 0.816
# 266.Percussion: 0.027
# 266.Musical instrument: 0.020
# 266.Inside, small room: 0.019
# 267.Inside, small room: 0.426
# 267.Printer: 0.195
# 267.Shuffle: 0.122
# 267.Inside, large room or hall: 0.091
# 267.Mechanisms: 0.073
# 268.Inside, small room: 0.347
# 268.Bouncing: 0.157
# 268.Door: 0.156
# 268.Drawer open or close: 0.127
# 268.Sliding door: 0.118
# 269.Crack: 0.822
# 269.Scissors: 0.738
# 269.Shuffling cards: 0.667
# 269.Coin (dropping): 0.627
# 269.Crunch: 0.482
# 270.Knock: 0.935
# 270.Door: 0.514
# 270.Bouncing: 0.473
# 270.Tap: 0.181
# 270.Inside, small room: 0.094
# 271.Cap gun: 0.455
# 271.Chop: 0.413
# 271.Wood: 0.333
# 271.Gunshot, gunfire: 0.273
# 271.Explosion: 0.199
# 272.Typing: 0.721
# 293.Knock: 0.938
# 293.Door: 0.489
# 293.Whack, thwack: 0.334
# 293.Bouncing: 0.312
# 293.Thunk: 0.266
# 294.Inside, small room: 0.284
# 294.Percussion: 0.079
# 294.Wood block: 0.062
# 294.Hands: 0.047
# 294.Animal: 0.046
# 295.Knock: 0.442
# 295.Crack: 0.323
# 295.Tap: 0.302
# 295.Door: 0.297
# 295.Typing: 0.198
# 296.Inside, small room: 0.169
# 296.Percussion: 0.101
# 296.Ping: 0.096
# 296.Inside, large room or hall: 0.086
# 296.Musical instrument: 0.076
# 297.Sliding door: 0.468
# 297.Door: 0.303
# 297.Inside, large room or hall: 0.205
# 297.Slam: 0.170
# 297.Inside, small room: 0.156
# 298.Hands: 0.664
# 298.Clapping: 0.368
# 298.Inside, small room: 0.318
# 298.Slap, smack: 0.312
# 298.Ping: 0.095
# 299.Walk, footsteps: 0.511
# 299.Crackle: 0.379
# 299.Fire: 0.323
# 299.Crumpling, crinkling: 0.175
# 299.Inside, small room: 0.122
# 300.Inside, small room: 0.620
# 300.Scissors: 0.075
# 300.Shuffling cards: 0.071
# 300.Biting: 0.021
# 300.Mechanisms: 0.020
# 301.Knock: 0.808
# 301.Thunk: 0.629
# 301.Door: 0.508
# 301.Thump, thud: 0.379
# 301.Tap: 0.359
# 302.Typing: 0.434
# 302.Computer keyboard: 0.416
# 302.Sound effect: 0.175
# 302.Scratch: 0.128
# 302.Wood block: 0.104
# 303.Door: 0.524
# 303.Tap: 0.377
# 303.Arrow: 0.232
# 303.Typewriter: 0.142
# 303.Thump, thud: 0.117
# 304.Inside, small room: 0.426
# 304.Scratch: 0.406
# 304.Writing: 0.340
# 304.Tearing: 0.142
# 304.Scissors: 0.086
# 305.Inside, small room: 0.393
# 305.Scratch: 0.075
# 305.Writing: 0.054
# 305.Wood: 0.044
# 305.Scratching (performance technique): 0.041
# 306.Hands: 0.276
# 306.Finger snapping: 0.168
# 306.Slap, smack: 0.131
# 306.Whip: 0.130
# 306.Inside, small room: 0.124
# 307.Hands: 0.776
# 307.Door: 0.693
# 307.Tap: 0.690
# 307.Clapping: 0.416
# 307.Slap, smack: 0.153
# 308.Chicken, rooster: 0.454
# 308.Fowl: 0.380
# 308.Livestock, farm animals, working animals: 0.305
# 308.Animal: 0.244
# 308.Cluck: 0.240
# 309.Tap: 0.111
# 309.Inside, small room: 0.108
# 309.Speech: 0.093
# 309.Door: 0.090
# 309.Knock: 0.046
# 310.Music: 0.657
# 310.Tambourine: 0.486
# 310.Percussion: 0.379
# 310.Musical instrument: 0.181
# 310.Rattle (instrument): 0.090
# 311.Inside, small room: 0.376
# 311.Hands: 0.132
# 311.Bouncing: 0.080
# 311.Tap: 0.037
# 311.Slap, smack: 0.035
# 312.Beatboxing: 0.261
# 312.Door: 0.246
# 312.Fart: 0.213
# 312.Walk, footsteps: 0.202
# 312.Livestock, farm animals, working animals: 0.171
# 313.Inside, small room: 0.318
# 313.Bouncing: 0.105
# 313.Shuffle: 0.100
# 313.Inside, large room or hall: 0.070
# 313.Door: 0.069
# 377.Dishes, pots, and pans: 0.027
# 377.Scissors: 0.023
# 378.Silence: 0.619
# 378.Inside, small room: 0.217
# 378.Speech: 0.008
# 378.Inside, large room or hall: 0.003
# 378.Writing: 0.002
# 379.Inside, small room: 0.266
# 379.Beatboxing: 0.133
# 379.Speech: 0.055
# 379.Scratching (performance technique): 0.051
# 379.Inside, large room or hall: 0.048
# 380.Crack: 0.841
# 380.Crunch: 0.580
# 380.Breaking: 0.408
# 380.Tearing: 0.362
# 380.Crushing: 0.275
# 381.Inside, small room: 0.217
# 381.Hands: 0.191
# 381.Bouncing: 0.149
# 381.Tap: 0.122
# 381.Door: 0.115
# 382.Hands: 0.417
# 382.Inside, small room: 0.375
# 382.Shuffling cards: 0.340
# 382.Slap, smack: 0.332
# 382.Chopping (food): 0.288
# 383.Inside, small room: 0.509
# 383.Typing: 0.077
# 383.Typewriter: 0.062
# 383.Animal: 0.021
# 383.Inside, large room or hall: 0.017
# 384.Shuffling cards: 0.374
# 384.Chopping (food): 0.223
# 384.Hands: 0.207
# 384.Slap, smack: 0.207
# 384.Inside, small room: 0.200
# 385.Whack, thwack: 0.161
# 385.Horse: 0.115
# 385.Livestock, farm animals, working animals: 0.114
# 385.Sound effect: 0.087
# 385.Door: 0.080
# 386.Tap: 0.574
# 386.Door: 0.535
# 386.Clapping: 0.287
# 386.Thump, thud: 0.237
# 386.Ping: 0.232
# 387.Knock: 0.500
# 387.Door: 0.317
# 387.Bouncing: 0.218
# 387.Tap: 0.152
# 387.Inside, small room: 0.102
# 388.Inside, small room: 0.520
# 388.Door: 0.141
# 388.Inside, large room or hall: 0.080
# 388.Sliding door: 0.072
# 388.Tap: 0.070
# 389.Chop: 0.438
# 389.Wood: 0.308
# 389.Whack, thwack: 0.243
# 389.Door: 0.209
# 389.Breaking: 0.149
# 390.Typing: 0.643
# 390.Computer keyboard: 0.499
# 390.Typewriter: 0.373
# 390.Percussion: 0.136
# 390.Wood block: 0.096
# 391.Bouncing: 0.705
# 391.Chopping (food): 0.470
# 391.Knock: 0.417
# 391.Shuffling cards: 0.243
# 391.Inside, small room: 0.242
# 392.Inside, small room: 0.364
# 392.Scissors: 0.047
# 392.Shuffling cards: 0.041
# 392.Hands: 0.037
# 392.Rattle (instrument): 0.031
# 393.Typewriter: 0.258
# 393.Typing: 0.250
# 393.Rattle (instrument): 0.212
# 393.Computer keyboard: 0.140
# 393.Percussion: 0.139
# 394.Crack: 0.984
# 394.Crushing: 0.943
# 394.Breaking: 0.841
# 394.Crunch: 0.758
# 394.Shuffling cards: 0.736
# 395.Knock: 0.831
# 395.Chop: 0.733
# 395.Whack, thwack: 0.502
# 395.Wood: 0.471
# 395.Door: 0.431
# 396.Horse: 0.279
# 396.Clip-clop: 0.242
# 396.Inside, small room: 0.211
# 396.Livestock, farm animals, working animals: 0.118
# 396.Door: 0.107
# 397.Typewriter: 0.383
# 397.Typing: 0.242
# 397.Chopping (food): 0.145
# 397.Shuffling cards: 0.131
# 397.Inside, small room: 0.129
# 398.Typing: 0.947
# 398.Typewriter: 0.924
# 398.Computer keyboard: 0.660
# 398.Music: 0.050
# 398.Percussion: 0.021
# 399.Inside, small room: 0.228
# 399.Music: 0.093
# 399.Percussion: 0.053
# 399.Musical instrument: 0.047
# 399.Silence: 0.041
# 400.Inside, small room: 0.395
# 400.Wood: 0.055
# 400.Door: 0.051
# 400.Percussion: 0.025
# 400.Inside, large room or hall: 0.023
# 401.Music: 0.380
# 401.Wood block: 0.272
# 401.Percussion: 0.169
# 401.Musical instrument: 0.157
# 401.Rattle (instrument): 0.102
# 402.Bouncing: 0.425
# 402.Inside, small room: 0.355
# 402.Door: 0.198
# 402.Knock: 0.180
# 402.Tap: 0.127
# 403.Inside, small room: 0.259
# 403.Chopping (food): 0.177
# 403.Scratch: 0.169
# 403.Shuffling cards: 0.140
# 403.Tearing: 0.115
# 404.Dog: 0.384
# 404.Domestic animals, pets: 0.383
# 404.Animal: 0.185
# 404.Inside, small room: 0.163
# 404.Whimper (dog): 0.146
# 405.Music: 0.627
# 405.Inside, small room: 0.024
# 405.Percussion: 0.018
# 405.Inside, large room or hall: 0.012
# 405.Drum: 0.011
# 406.Crumpling, crinkling: 0.816
# 406.Crackle: 0.432
# 406.Fire: 0.289
# 406.Inside, small room: 0.205
# 406.Tearing: 0.149
# 407.Inside, small room: 0.293
# 407.Shuffle: 0.201
# 407.Inside, large room or hall: 0.076
# 407.Tap: 0.065
# 407.Hands: 0.054
# 408.Music: 0.956
# 408.Percussion: 0.222
# 408.Drum machine: 0.125
# 408.Musical instrument: 0.110
# 408.Drum kit: 0.064
# 409.Inside, small room: 0.451
# 409.Shuffle: 0.164
# 409.Inside, large room or hall: 0.098
# 409.Tap: 0.076
# 409.Door: 0.068
# 410.Inside, small room: 0.239
# 410.Tap: 0.151
# 410.Bouncing: 0.133
# 410.Door: 0.095
# 410.Knock: 0.046
# 411.Chop: 0.800
# 411.Chopping (food): 0.662
# 411.Wood: 0.518
# 411.Cap gun: 0.427
# 411.Whack, thwack: 0.371
# 412.Domestic animals, pets: 0.272
# 412.Dog: 0.251
# 412.Animal: 0.202
# 412.Inside, small room: 0.135
# 412.Musical instrument: 0.064
# 413.Chopping (food): 0.909
# 413.Whack, thwack: 0.655
# 413.Wood: 0.573
# 413.Chop: 0.377
# 413.Cap gun: 0.281
# 414.Crushing: 0.550
# 414.Inside, small room: 0.390
# 414.Crackle: 0.311
# 414.Crumpling, crinkling: 0.237
# 414.Fire: 0.197
# 415.Bouncing: 0.277
# 415.Inside, small room: 0.241
# ...
# 106.Percussion: 0.113
# 107.Scratch: 0.318
# 107.Scrape: 0.308
# 107.Fart: 0.265
# 107.Rattle: 0.180
# 107.Typing: 0.119
# 108.Cap gun: 0.755
# 108.Explosion: 0.720
# 108.Gunshot, gunfire: 0.559
# 108.Fireworks: 0.307
# 108.Chop: 0.231
# 109.Inside, small room: 0.429
# 109.Crumpling, crinkling: 0.233
# 109.Typing: 0.057
# 109.Animal: 0.035
# 109.Computer keyboard: 0.031
# 110.Walk, footsteps: 0.312
# 110.Inside, small room: 0.271
# 110.Crackle: 0.129
# 110.Inside, large room or hall: 0.124
# 110.Fire: 0.094
# 111.Shuffling cards: 0.619
# 111.Knock: 0.554
# 111.Bouncing: 0.409
# 111.Inside, small room: 0.374
# 111.Door: 0.220
# 112.Bouncing: 0.467
# 112.Whip: 0.310
# 112.Hands: 0.307
# 112.Slap, smack: 0.283
# 112.Inside, small room: 0.242
# 113.Tap: 0.995
# 113.Door: 0.993
# 113.Speech: 0.027
# 113.Thump, thud: 0.013
# 113.Arrow: 0.012
# 114.Tap: 0.964
# 114.Door: 0.962
# 114.Thump, thud: 0.093
# 114.Arrow: 0.070
# 114.Speech: 0.037
# 115.Tap: 0.807
# 115.Door: 0.799
# 115.Speech: 0.050
# 115.Liquid: 0.036
# 115.Pour: 0.017
# 116.Tap: 0.834
# 116.Door: 0.783
# 116.Arrow: 0.062
# 116.Thump, thud: 0.056
# 116.Speech: 0.052
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 30
#      28 counter += 1
#      29 audio_file = os.path.join(test_dir, cls, f)
# ---> 30 wav_data = load_wav_16k_mono(audio_file)
#      31 class_scores, embeddings, _ = model(wav_data)
#      32 # 상위 5개 예측 클래스 출력
#
# Cell In[9], line 16, in load_wav_16k_mono(filename)
#      14 wav = tf.squeeze(wav, axis=-1)
#      15 sample_rate = tf.cast(sample_rate, dtype=tf.int64)
# ---> 16 wav = tfio.audio.resample(wav, rate_in=sample_rate, rate_out=16000)
#      17 return wav
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow_io/python/ops/audio_ops.py:469, in resample(input, rate_in, rate_out, name)
#     464 def f(i):
#     465     return core_ops.io_audio_resample(
#     466         i, rate_in=rate_in, rate_out=rate_out, name=name
#     467     )
# --> 469 value = tf.vectorized_map(f, input)
#     471 def g1():
#     472     return tf.squeeze(value, [0, -1])
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/parallel_for/control_flow_ops.py:565, in vectorized_map(fn, elems, fallback_to_while_loop, warn)
#     562 else:
#     563   batch_size = max(static_first_dims)
# --> 565 return pfor(
#     566     loop_fn,
#     567     batch_size,
#     568     fallback_to_while_loop=fallback_to_while_loop,
#     569     warn=warn)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/parallel_for/control_flow_ops.py:214, in pfor(loop_fn, iters, fallback_to_while_loop, parallel_iterations, warn)
#     211     def_function.run_functions_eagerly(False)
#     212   f = def_function.function(f)
# --> 214 outputs = f()
#     215 if functions_run_eagerly is not None:
#     216   def_function.run_functions_eagerly(functions_run_eagerly)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:894, in Function.__call__(self, *args, **kwds)
#     891 compiler = "xla" if self._jit_compile else "nonXla"
#     893 with OptionalXlaContext(self._jit_compile):
# --> 894   result = self._call(*args, **kwds)
#     896 new_tracing_count = self.experimental_get_tracing_count()
#     897 without_tracing = (tracing_count == new_tracing_count)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:942, in Function._call(self, *args, **kwds)
#     939 try:
#     940   # This is the first call of __call__, so we have to initialize.
#     941   initializers = []
# --> 942   self._initialize(args, kwds, add_initializers_to=initializers)
#     943 finally:
#     944   # At this point we know that the initialization is complete (or less
#     945   # interestingly an exception was raised) so we no longer need a lock.
#     946   self._lock.release()
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:763, in Function._initialize(self, args, kwds, add_initializers_to)
#     760 self._lifted_initializer_graph = lifted_initializer_graph
#     761 self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     762 self._concrete_variable_creation_fn = (
# --> 763     self._variable_creation_fn    # pylint: disable=protected-access
#     764     ._get_concrete_function_internal_garbage_collected(
#     765         *args, **kwds))
#     767 def invalid_creator_scope(*unused_args, **unused_kwds):
#     768   """Disables variable creation."""
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:171, in TracingCompiler._get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#     169 """Returns a concrete function which cleans up its graph function."""
#     170 with self._lock:
# --> 171   concrete_function, _ = self._maybe_define_concrete_function(args, kwargs)
#     172 return concrete_function
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:166, in TracingCompiler._maybe_define_concrete_function(self, args, kwargs)
#     163   args = self.input_signature
#     164   kwargs = {}
# --> 166 return self._maybe_define_function(args, kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:396, in TracingCompiler._maybe_define_function(self, args, kwargs)
#     393   args = placeholder_bound_args.args
#     394 kwargs = placeholder_bound_args.kwargs
# --> 396 concrete_function = self._create_concrete_function(
#     397     args, kwargs, func_graph)
#     399 # TODO(b/263520817): Remove access to private attribute.
#     400 graph_capture_container = concrete_function.graph._function_captures  # pylint: disable=protected-access
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:300, in TracingCompiler._create_concrete_function(self, args, kwargs, func_graph)
#     296 else:
#     297   arg_names = base_arg_names
#     299 concrete_function = monomorphic_function.ConcreteFunction(
# --> 300     func_graph_module.func_graph_from_py_func(
#     301         self._name,
#     302         self._python_function,
#     303         args,
#     304         kwargs,
#     305         None,
#     306         func_graph=func_graph,
#     307         autograph=self._autograph,
#     308         autograph_options=self._autograph_options,
#     309         arg_names=arg_names,
#     310         capture_by_value=self._capture_by_value,
#     311         create_placeholders=False),
#     312     self._function_attributes,
#     313     spec=self.function_spec,
#     314     # Tell the ConcreteFunction to clean up its graph once it goes out of
#     315     # scope. This is not the default behavior since it gets used in some
#     316     # places (like Keras) where the FuncGraph lives longer than the
#     317     # ConcreteFunction.
#     318     shared_func_graph=False)
#     319 return concrete_function
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/func_graph.py:1214, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders, acd_record_initial_resource_uses)
#    1211 else:
#    1212   _, original_func = tf_decorator.unwrap(python_func)
# -> 1214 func_outputs = python_func(*func_args, **func_kwargs)
#    1216 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1217 # TensorArrays and `None`s.
#    1218 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:667, in Function._compiler_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     663 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     664   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     665   # the function a weak reference to itself to avoid a reference cycle.
#     666   with OptionalXlaContext(compile_with_xla):
# --> 667     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     668   return out
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/func_graph.py:1189, in func_graph_from_py_func.<locals>.autograph_handler(*args, **kwargs)
#    1187 # TODO(mdan): Push this block higher in tf.function's call stack.
#    1188 try:
# -> 1189   return autograph.converted_call(
#    1190       original_func,
#    1191       args,
#    1192       kwargs,
#    1193       options=autograph.ConversionOptions(
#    1194           recursive=True,
#    1195           optional_features=autograph_options,
#    1196           user_requested=True,
#    1197       ))
#    1198 except Exception as e:  # pylint:disable=broad-except
#    1199   if hasattr(e, "ag_error_metadata"):
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/impl/api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File /tmp/__autograph_generated_file4f7pyc85.py:17, in outer_factory.<locals>.inner_factory.<locals>.tf__f()
#      15 try:
#      16     do_return = True
# ---> 17     retval_ = ag__.converted_call(ag__.ld(_pfor_impl), (ag__.ld(loop_fn), ag__.ld(iters)), dict(fallback_to_while_loop=ag__.ld(fallback_to_while_loop), parallel_iterations=ag__.ld(parallel_iterations), warn=ag__.ld(warn)), fscope)
#      18 except:
#      19     do_return = False
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/impl/api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/impl/api.py:458, in _call_unconverted(f, args, kwargs, options, update_cache)
#     455   return f.__self__.call(args, kwargs)
#     457 if kwargs is not None:
# --> 458   return f(*args, **kwargs)
#     459 return f(*args)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/parallel_for/control_flow_ops.py:340, in _pfor_impl(loop_fn, iters, fallback_to_while_loop, parallel_iterations, pfor_config, warn)
#     338     flattened_output_tensors = []
#     339     for loop_fn_output in nest.flatten(loop_fn_output_tensors):
# --> 340       output = converter.convert(loop_fn_output)
#     341       flattened_output_tensors.append(output)
#     342 else:
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/parallel_for/pfor.py:1427, in PFor.convert(self, y)
#    1425 if isinstance(output, WrappedTensor):
#    1426   assert isinstance(y, ops.Tensor)
# -> 1427   return self._unwrap_or_tile(output)
#    1428 else:
#    1429   assert isinstance(y, ops.Operation)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/parallel_for/pfor.py:1406, in PFor._unwrap_or_tile(self, wrapped_tensor)
#    1404   return output
#    1405 else:
# -> 1406   return _stack(output, self._loop_len_vector).t
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/parallel_for/pfor.py:160, in _stack(t, length)
#     158 length = array_ops.reshape(length, [-1])
#     159 multiples = array_ops.concat([length, ones], 0)
# --> 160 t = array_ops.tile(array_ops.expand_dims(t, 0), multiples)
#     161 return wrap(t, True)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_array_ops.py:11783, in tile(input, multiples, name)
#   11781 # Add nodes to the TensorFlow graph.
#   11782 try:
# > 11783   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   11784       "Tile", input=input, multiples=multiples, name=name)
#   11785 except (TypeError, ValueError):
#   11786   _result = _dispatch.dispatch(
#   11787         tile, (), dict(input=input, multiples=multiples, name=name)
#   11788       )
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/op_def_library.py:795, in _apply_op_helper(op_type_name, name, **keywords)
#     790 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     791                         if arg.is_ref]
#     792 with _MaybeColocateWith(must_colocate_inputs):
#     793   # Add Op to graph
#     794   # pylint: disable=protected-access
# --> 795   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     796                              name=scope, input_types=input_types,
#     797                              attrs=attr_protos, op_def=op_def)
#     799 # `outputs` is returned as a separate return value so that the output
#     800 # tensors can the `op` per se can be decoupled so that the
#     801 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     802 # for more details.
#     803 outputs = op.outputs
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/func_graph.py:707, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     705   inp = self.capture(inp)
#     706   captured_inputs.append(inp)
# --> 707 return super()._create_op_internal(  # pylint: disable=protected-access
#     708     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     709     compute_device)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:3814, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3811 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    3812 # Session.run call cannot occur between creating and mutating the op.
#    3813 with self._mutation_lock():
# -> 3814   ret = Operation(
#    3815       node_def,
#    3816       self,
#    3817       inputs=inputs,
#    3818       output_types=dtypes,
#    3819       control_inputs=control_inputs,
#    3820       input_types=input_types,
#    3821       original_op=self._default_original_op,
#    3822       op_def=op_def)
#    3823   self._create_op_helper(ret, compute_device=compute_device)
#    3824 return ret
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:2112, in Operation.__init__(***failed resolving arguments***)
#    2109     control_input_ops.append(control_op)
#    2111 # Initialize c_op from node_def and other inputs
# -> 2112 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    2113 self._init_from_c_op(c_op=c_op, g=g)
#    2115 self._original_op = original_op
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/framework/ops.py:1970, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1966   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1967                                          serialized)
#    1969 try:
# -> 1970   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1971 except errors.InvalidArgumentError as e:
#    1972   # Convert to ValueError for backwards compatibility.
#    1973   raise ValueError(e.message)
#
# KeyboardInterrupt:
