# %%
import librosa, numpy as np
from model.mobilenet_mfcc import mobilenet_v2_mfcc
import torch, time, os
from sklearn.metrics import f1_score

# wav 파일을 MFCC로 변환하는 함수
def wav_to_mfcc(file_path, n_mfcc=40, max_len=100):
    y, sr = librosa.load(file_path, sr=16000)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    
    # MFCC의 길이를 max_len으로 맞추기
    if mfcc.shape[1] < max_len:
        mfcc = np.pad(mfcc, ((0, 0), (0, max_len - mfcc.shape[1])), mode='constant')
    else:
        mfcc = mfcc[:, :max_len]
    
    return mfcc

def predict_single_file(file_path, model, class_names, device='cuda'):
    """단일 WAV 파일에 대한 예측을 수행합니다."""
    # 오디오 파일 로드 및 MFCC 변환
    mfcc = wav_to_mfcc(file_path)
    
    # MFCC를 모델 입력 형식으로 변환
    mfcc = np.expand_dims(mfcc, axis=(0, 1))  # (1, 1, n_mfcc, max_len) 형태로 변환
    mfcc_tensor = torch.FloatTensor(mfcc).to(device)
    
    # 예측 수행
    model.eval()
    with torch.no_grad():
        outputs = model(mfcc_tensor)
        probabilities = torch.nn.functional.softmax(outputs, dim=1)
        predicted_class = torch.argmax(probabilities, dim=1).item()
    
    # 결과 반환
    predicted_label = class_names[predicted_class]
    confidence = probabilities[0][predicted_class].item()
    
    return predicted_label, confidence

# %%
binary_class = ['home_noise', 'not_noise']
class_names = ['가구끄는소리',
 '강아지짓는소리',
 '고양이우는소리',
 '골프퍼팅(골굴리는소리)',
 '드럼세탁기소리',
 '런닝머신에서뛰는소리',
 '망치질소리',
 '문여닫는소리',
 '바이올린연주소리',
 '샤워할때물소리',
 '식기세척기소리',
 '아이들발걸음소리',
 '어른발걸음소리',
 '진공청소기소리',
 '통돌이세탁기소리',
 '피아노연주소리',
 '화장실물내리는소리']

# 모델 로딩
model = mobilenet_v2_mfcc(num_classes=len(class_names))
model.load_state_dict(torch.load('model/mobilenet_mfcc_model2424.pth'))
# GPU 사용 가능 시 GPU로 모델 이동
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
## 1. 노이즈 유무 예측
# stime = time.time()
count = 0
correct_count = 0
y_true = []
y_pred = []
target_dir = './test_data/noise_or_not'
for directory in os.listdir(target_dir):
    for file in os.listdir(os.path.join(target_dir, directory)):
        if file.endswith('wav'):
            wavpath = os.path.join(target_dir, directory, file)
            count += 1
            _, confidence = predict_single_file(wavpath, model, class_names, device)
            predicted_label = 'home_noise' if confidence > 0.6 else 'not_noise'
            # print(time.time()-stime)
            y_true.append(binary_class.index(directory))
            y_pred.append(binary_class.index(predicted_label))
            if predicted_label == directory:
                correct_count += 1
                res = 'OK'
            else:
                res = 'FAIL'
            print(f"파일명: {file}, 실제: {directory}, 예측: {predicted_label}, 결과: {res}")
print("------------------------------")
print(f"총 파일 수: {count}개, 올바른 예측: {correct_count}개")

# F1 스코어 계산
f1 = f1_score(y_true, y_pred)
print(f'F1 Score: {f1:.4f}')
# Out:
# 파일명: normal3159.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal1069.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal2478.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal2947.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal495.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal1646.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal3287.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal3422.wav, 실제: not_noise, 예측: home_noise, 결과: FAIL
# 파일명: normal1224.wav, 실제: not_noise, 예측: home_noise, 결과: FAIL
# 파일명: normal1382.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal1993.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal1586.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal1385.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal608.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal661.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal2088.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal414.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal1799.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal935.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal1889.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal2854.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal939.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal3880.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal2331.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal3918.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal132.wav, 실제: not_noise, 예측: home_noise, 결과: FAIL
# 파일명: normal2762.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal1760.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal3303.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal2219.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal1488.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal3656.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal3023.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal1396.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal2370.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal291.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal636.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal16.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal2349.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal3381.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal2639.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal1153.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal2692.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal74.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal2291.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal1426.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal401.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal2743.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal3619.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: normal3523.wav, 실제: not_noise, 예측: not_noise, 결과: OK
# 파일명: N-10_220929_A_3_c_09986_0.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220926_A_2_a_03395_3.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220927_A_3_f_13090_0.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_221006_A_2_c_06254_2.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_221010_A_3_f_13754_1.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220918_A_2_d_06870_1.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220926_A_3_b_08766_3.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_221001_A_3_d_11147_1.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220904_A_1_a_00731_6.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_221010_A_1_b_01771_1.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_221018_A_5_a_16368_0.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220923_A_3_e_12440_2.wav, 실제: home_noise, 예측: not_noise, 결과: FAIL
# 파일명: N-10_221020_A_2_c_06109_3.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220911_A_1_c_03211_18.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220918_A_4_b_15796_0.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220915_A_4_a_15025_0.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220928_A_3_a_08335_0.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_221003_A_3_f_13382_0.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220925_A_4_b_15564_3.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220919_A_1_a_00811_3.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220922_A_3_d_10720_3.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220914_A_2_a_03628_3.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220901_A_3_a_08346_0.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220923_A_1_c_02847_3.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220922_A_3_a_07799_0.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_221011_A_4_a_14785_0.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220926_A_2_b_04580_2.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220917_A_2_c_05396_2.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220919_A_3_b_09114_5.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_221101_A_5_b_18017_6.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220928_A_1_b_01950_2.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_221027_A_5_b_17744_3.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220925_A_3_c_10103_0.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220915_A_1_c_02411_0.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220831_A_4_b_15333_1.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220916_A_5_a_16585_3.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220904_A_3_b_08785_0.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220923_A_3_e_11928_4.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220913_A_1_a_00410_2.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_221007_A_4_a_14704_0.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220930_A_2_d_06779_1.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220906_A_1_b_01924_2.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_221101_A_5_b_17455_4.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220916_A_3_e_11754_1.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220903_A_2_b_04420_4.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220916_A_3_d_11097_1.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_221008_A_5_a_16419_3.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220907_A_2_a_03440_0.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_220916_A_3_c_10603_1.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# 파일명: N-10_221004_A_2_d_07407_4.wav, 실제: home_noise, 예측: home_noise, 결과: OK
# ------------------------------
# 총 파일 수: 100개, 올바른 예측: 96개
# F1 Score: 0.9592

# %%
## 2. 노이즈 종류 예측
# stime = time.time()
stime = time.time()
count = 0
correct_count = 0
y_true = []
y_pred = []
target_dir = './test_data/classification'
for directory in os.listdir(target_dir):
    for file in os.listdir(os.path.join(target_dir, directory)):
        if file.endswith('wav'):
            wavpath = os.path.join(target_dir, directory, file)
            count += 1
            predicted_label, confidence = predict_single_file(wavpath, model, class_names, device)
            # print(time.time()-stime)
            y_true.append(class_names.index(directory))
            y_pred.append(class_names.index(predicted_label))
            if predicted_label == directory:
                correct_count += 1
                res = 'OK'
            else:
                res = 'FAIL'
            print(f"파일명: {file}, 실제: {directory}, 예측: {predicted_label}, 결과: {res}")
                
print("------------------------------")
print(f"총 파일 수: {count}개, 올바른 예측: {correct_count}개")

# F1 스코어 계산
f1 = f1_score(y_true, y_pred, average='macro')
print(f'F1 Score: {f1:.4f}')
# Out:
# 파일명: N-10_221001_A_4_a_14123_1.wav, 실제: 바이올린연주소리, 예측: 바이올린연주소리, 결과: OK
# 파일명: N-10_220915_A_4_a_15025_0.wav, 실제: 바이올린연주소리, 예측: 바이올린연주소리, 결과: OK
# 파일명: N-10_221001_A_4_a_13908_0.wav, 실제: 바이올린연주소리, 예측: 바이올린연주소리, 결과: OK
# 파일명: N-10_220918_A_4_a_14235_1.wav, 실제: 바이올린연주소리, 예측: 바이올린연주소리, 결과: OK
# 파일명: N-10_220920_A_4_a_14266_2.wav, 실제: 바이올린연주소리, 예측: 바이올린연주소리, 결과: OK
# 파일명: N-10_221011_A_4_a_14785_0.wav, 실제: 바이올린연주소리, 예측: 바이올린연주소리, 결과: OK
# 파일명: N-10_221008_A_4_a_14593_1.wav, 실제: 바이올린연주소리, 예측: 바이올린연주소리, 결과: OK
# 파일명: N-10_221007_A_4_a_14704_0.wav, 실제: 바이올린연주소리, 예측: 바이올린연주소리, 결과: OK
# 파일명: N-10_221011_A_4_a_14773_7.wav, 실제: 바이올린연주소리, 예측: 바이올린연주소리, 결과: OK
# 파일명: N-10_221010_A_4_a_14759_1.wav, 실제: 바이올린연주소리, 예측: 바이올린연주소리, 결과: OK
# 파일명: N-10_220923_A_3_a_07755_0.wav, 실제: 화장실물내리는소리, 예측: 화장실물내리는소리, 결과: OK
# 파일명: N-10_220901_A_3_a_08367_0.wav, 실제: 화장실물내리는소리, 예측: 화장실물내리는소리, 결과: OK
# 파일명: N-10_220925_A_3_a_08131_0.wav, 실제: 화장실물내리는소리, 예측: 화장실물내리는소리, 결과: OK
# 파일명: N-10_220928_A_3_a_08335_0.wav, 실제: 화장실물내리는소리, 예측: 화장실물내리는소리, 결과: OK
# 파일명: N-10_220921_A_3_a_08529_0.wav, 실제: 화장실물내리는소리, 예측: 화장실물내리는소리, 결과: OK
# 파일명: N-10_220901_A_3_a_08346_0.wav, 실제: 화장실물내리는소리, 예측: 화장실물내리는소리, 결과: OK
# 파일명: N-10_220922_A_3_a_07799_0.wav, 실제: 화장실물내리는소리, 예측: 화장실물내리는소리, 결과: OK
# 파일명: N-10_220905_A_3_a_08223_0.wav, 실제: 화장실물내리는소리, 예측: 화장실물내리는소리, 결과: OK
# 파일명: N-10_220910_A_3_a_08422_0.wav, 실제: 화장실물내리는소리, 예측: 화장실물내리는소리, 결과: OK
# 파일명: N-10_220923_A_3_a_07994_1.wav, 실제: 화장실물내리는소리, 예측: 화장실물내리는소리, 결과: OK
# 파일명: N-10_220910_A_1_c_03198_18.wav, 실제: 망치질소리, 예측: 망치질소리, 결과: OK
# 파일명: N-10_220925_A_1_c_03056_1.wav, 실제: 망치질소리, 예측: 망치질소리, 결과: OK
# 파일명: N-10_220913_A_1_c_02592_0.wav, 실제: 망치질소리, 예측: 망치질소리, 결과: OK
# 파일명: N-10_220914_A_1_c_02609_5.wav, 실제: 망치질소리, 예측: 망치질소리, 결과: OK
# 파일명: N-10_220925_A_1_c_02436_2.wav, 실제: 망치질소리, 예측: 아이들발걸음소리, 결과: FAIL
# 파일명: N-10_220914_A_1_c_02159_0.wav, 실제: 망치질소리, 예측: 망치질소리, 결과: OK
# 파일명: N-10_220923_A_1_c_02847_3.wav, 실제: 망치질소리, 예측: 망치질소리, 결과: OK
# 파일명: N-10_220908_A_1_c_02731_3.wav, 실제: 망치질소리, 예측: 망치질소리, 결과: OK
# 파일명: N-10_220919_A_1_c_02885_0.wav, 실제: 망치질소리, 예측: 어른발걸음소리, 결과: FAIL
# 파일명: N-10_220923_A_1_c_02464_3.wav, 실제: 망치질소리, 예측: 망치질소리, 결과: OK
# 파일명: N-10_221101_A_5_b_17812_4.wav, 실제: 고양이우는소리, 예측: 고양이우는소리, 결과: OK
# 파일명: N-10_221030_A_5_b_17363_1.wav, 실제: 고양이우는소리, 예측: 고양이우는소리, 결과: OK
# 파일명: N-10_221101_A_5_b_17455_0.wav, 실제: 고양이우는소리, 예측: 고양이우는소리, 결과: OK
# 파일명: N-10_221101_A_5_b_18017_6.wav, 실제: 고양이우는소리, 예측: 바이올린연주소리, 결과: FAIL
# 파일명: N-10_221027_A_5_b_17744_3.wav, 실제: 고양이우는소리, 예측: 고양이우는소리, 결과: OK
# 파일명: N-10_221101_A_5_b_17778_6.wav, 실제: 고양이우는소리, 예측: 고양이우는소리, 결과: OK
# 파일명: N-10_221101_A_5_b_18009_3.wav, 실제: 고양이우는소리, 예측: 고양이우는소리, 결과: OK
# 파일명: N-10_221028_A_5_b_17259_2.wav, 실제: 고양이우는소리, 예측: 고양이우는소리, 결과: OK
# 파일명: N-10_221101_A_5_b_17455_4.wav, 실제: 고양이우는소리, 예측: 고양이우는소리, 결과: OK
# 파일명: N-10_221101_A_5_b_17778_4.wav, 실제: 고양이우는소리, 예측: 고양이우는소리, 결과: OK
# 파일명: N-10_221001_A_2_d_06790_2.wav, 실제: 골프퍼팅(골굴리는소리), 예측: 골프퍼팅(골굴리는소리), 결과: OK
# 파일명: N-10_220918_A_2_d_06870_1.wav, 실제: 골프퍼팅(골굴리는소리), 예측: 골프퍼팅(골굴리는소리), 결과: OK
# 파일명: N-10_220928_A_2_d_06741_3.wav, 실제: 골프퍼팅(골굴리는소리), 예측: 골프퍼팅(골굴리는소리), 결과: OK
# 파일명: N-10_220918_A_2_d_06870_5.wav, 실제: 골프퍼팅(골굴리는소리), 예측: 골프퍼팅(골굴리는소리), 결과: OK
# 파일명: N-10_221003_A_2_d_06672_1.wav, 실제: 골프퍼팅(골굴리는소리), 예측: 골프퍼팅(골굴리는소리), 결과: OK
# 파일명: N-10_221003_A_2_d_06672_3.wav, 실제: 골프퍼팅(골굴리는소리), 예측: 골프퍼팅(골굴리는소리), 결과: OK
# 파일명: N-10_220925_A_2_d_06692_0.wav, 실제: 골프퍼팅(골굴리는소리), 예측: 골프퍼팅(골굴리는소리), 결과: OK
# 파일명: N-10_220930_A_2_d_06779_1.wav, 실제: 골프퍼팅(골굴리는소리), 예측: 골프퍼팅(골굴리는소리), 결과: OK
# 파일명: N-10_220920_A_2_d_06504_5.wav, 실제: 골프퍼팅(골굴리는소리), 예측: 골프퍼팅(골굴리는소리), 결과: OK
# 파일명: N-10_221004_A_2_d_07407_4.wav, 실제: 골프퍼팅(골굴리는소리), 예측: 골프퍼팅(골굴리는소리), 결과: OK
# 파일명: N-10_220918_A_1_a_00157_2.wav, 실제: 어른발걸음소리, 예측: 어른발걸음소리, 결과: OK
# 파일명: N-10_220904_A_1_a_00731_6.wav, 실제: 어른발걸음소리, 예측: 어른발걸음소리, 결과: OK
# 파일명: N-10_220905_A_1_a_00609_7.wav, 실제: 어른발걸음소리, 예측: 망치질소리, 결과: FAIL
# 파일명: N-10_220919_A_1_a_00811_3.wav, 실제: 어른발걸음소리, 예측: 어른발걸음소리, 결과: OK
# 파일명: N-10_220905_A_1_a_00608_2.wav, 실제: 어른발걸음소리, 예측: 어른발걸음소리, 결과: OK
# 파일명: N-10_220918_A_1_a_00794_2.wav, 실제: 어른발걸음소리, 예측: 어른발걸음소리, 결과: OK
# 파일명: N-10_220910_A_1_a_00246_4.wav, 실제: 어른발걸음소리, 예측: 어른발걸음소리, 결과: OK
# 파일명: N-10_220913_A_1_a_00410_2.wav, 실제: 어른발걸음소리, 예측: 어른발걸음소리, 결과: OK
# 파일명: N-10_220915_A_1_a_00904_3.wav, 실제: 어른발걸음소리, 예측: 어른발걸음소리, 결과: OK
# 파일명: N-10_220919_A_1_a_00063_7.wav, 실제: 어른발걸음소리, 예측: 어른발걸음소리, 결과: OK
# 파일명: N-10_220927_A_3_f_13090_0.wav, 실제: 식기세척기소리, 예측: 식기세척기소리, 결과: OK
# 파일명: N-10_221009_A_3_f_13505_4.wav, 실제: 식기세척기소리, 예측: 식기세척기소리, 결과: OK
# 파일명: N-10_221010_A_3_f_13754_1.wav, 실제: 식기세척기소리, 예측: 식기세척기소리, 결과: OK
# 파일명: N-10_220930_A_3_f_12879_4.wav, 실제: 식기세척기소리, 예측: 식기세척기소리, 결과: OK
# 파일명: N-10_220930_A_3_f_13322_0.wav, 실제: 식기세척기소리, 예측: 식기세척기소리, 결과: OK
# 파일명: N-10_221003_A_3_f_13382_0.wav, 실제: 식기세척기소리, 예측: 식기세척기소리, 결과: OK
# 파일명: N-10_221010_A_3_f_13654_4.wav, 실제: 식기세척기소리, 예측: 식기세척기소리, 결과: OK
# 파일명: N-10_221007_A_3_f_13470_4.wav, 실제: 식기세척기소리, 예측: 식기세척기소리, 결과: OK
# 파일명: N-10_220928_A_3_f_13854_0.wav, 실제: 식기세척기소리, 예측: 식기세척기소리, 결과: OK
# 파일명: N-10_221007_A_3_f_12959_3.wav, 실제: 식기세척기소리, 예측: 식기세척기소리, 결과: OK
# 파일명: N-10_221006_A_2_c_06254_2.wav, 실제: 런닝머신에서뛰는소리, 예측: 런닝머신에서뛰는소리, 결과: OK
# 파일명: N-10_221001_A_2_c_05458_3.wav, 실제: 런닝머신에서뛰는소리, 예측: 런닝머신에서뛰는소리, 결과: OK
# 파일명: N-10_221020_A_2_c_05877_0.wav, 실제: 런닝머신에서뛰는소리, 예측: 런닝머신에서뛰는소리, 결과: OK
# 파일명: N-10_221001_A_2_c_05451_4.wav, 실제: 런닝머신에서뛰는소리, 예측: 런닝머신에서뛰는소리, 결과: OK
# 파일명: N-10_221020_A_2_c_06109_3.wav, 실제: 런닝머신에서뛰는소리, 예측: 런닝머신에서뛰는소리, 결과: OK
# 파일명: N-10_221003_A_2_c_05484_3.wav, 실제: 런닝머신에서뛰는소리, 예측: 런닝머신에서뛰는소리, 결과: OK
# 파일명: N-10_221013_A_2_c_05661_3.wav, 실제: 런닝머신에서뛰는소리, 예측: 런닝머신에서뛰는소리, 결과: OK
# 파일명: N-10_220917_A_2_c_05396_2.wav, 실제: 런닝머신에서뛰는소리, 예측: 런닝머신에서뛰는소리, 결과: OK
# 파일명: N-10_221016_A_2_c_06062_3.wav, 실제: 런닝머신에서뛰는소리, 예측: 런닝머신에서뛰는소리, 결과: OK
# 파일명: N-10_221006_A_2_c_06260_4.wav, 실제: 런닝머신에서뛰는소리, 예측: 런닝머신에서뛰는소리, 결과: OK
# 파일명: N-10_220928_A_1_b_01139_1.wav, 실제: 아이들발걸음소리, 예측: 아이들발걸음소리, 결과: OK
# 파일명: N-10_221010_A_1_b_01771_1.wav, 실제: 아이들발걸음소리, 예측: 아이들발걸음소리, 결과: OK
# 파일명: N-10_221006_A_1_b_01998_0.wav, 실제: 아이들발걸음소리, 예측: 어른발걸음소리, 결과: FAIL
# 파일명: N-10_220911_A_1_b_01256_0.wav, 실제: 아이들발걸음소리, 예측: 어른발걸음소리, 결과: FAIL
# 파일명: N-10_220928_A_1_b_01950_2.wav, 실제: 아이들발걸음소리, 예측: 아이들발걸음소리, 결과: OK
# 파일명: N-10_221004_A_1_b_01649_0.wav, 실제: 아이들발걸음소리, 예측: 아이들발걸음소리, 결과: OK
# 파일명: N-10_220906_A_1_b_01924_2.wav, 실제: 아이들발걸음소리, 예측: 어른발걸음소리, 결과: FAIL
# 파일명: N-10_220921_A_1_b_01259_0.wav, 실제: 아이들발걸음소리, 예측: 어른발걸음소리, 결과: FAIL
# 파일명: N-10_220929_A_1_b_01327_2.wav, 실제: 아이들발걸음소리, 예측: 망치질소리, 결과: FAIL
# 파일명: N-10_221002_A_1_b_01428_2.wav, 실제: 아이들발걸음소리, 예측: 아이들발걸음소리, 결과: OK
# 파일명: N-10_220929_A_3_c_09986_0.wav, 실제: 드럼세탁기소리, 예측: 식기세척기소리, 결과: FAIL
# 파일명: N-10_220924_A_3_c_10014_4.wav, 실제: 드럼세탁기소리, 예측: 드럼세탁기소리, 결과: OK
# 파일명: N-10_220925_A_3_c_10103_1.wav, 실제: 드럼세탁기소리, 예측: 드럼세탁기소리, 결과: OK
# 파일명: N-10_220920_A_3_c_10335_2.wav, 실제: 드럼세탁기소리, 예측: 드럼세탁기소리, 결과: OK
# 파일명: N-10_220928_A_3_c_09762_4.wav, 실제: 드럼세탁기소리, 예측: 드럼세탁기소리, 결과: OK
# 파일명: N-10_220925_A_3_c_10103_0.wav, 실제: 드럼세탁기소리, 예측: 드럼세탁기소리, 결과: OK
# 파일명: N-10_220929_A_3_c_09781_1.wav, 실제: 드럼세탁기소리, 예측: 드럼세탁기소리, 결과: OK
# 파일명: N-10_220928_A_3_c_09979_4.wav, 실제: 드럼세탁기소리, 예측: 드럼세탁기소리, 결과: OK
# 파일명: N-10_220920_A_3_c_10641_0.wav, 실제: 드럼세탁기소리, 예측: 가구끄는소리, 결과: FAIL
# 파일명: N-10_220916_A_3_c_10603_1.wav, 실제: 드럼세탁기소리, 예측: 드럼세탁기소리, 결과: OK
# 파일명: N-10_220926_A_3_b_08736_4.wav, 실제: 샤워할때물소리, 예측: 샤워할때물소리, 결과: OK
# 파일명: N-10_220926_A_3_b_08766_3.wav, 실제: 샤워할때물소리, 예측: 샤워할때물소리, 결과: OK
# 파일명: N-10_220919_A_3_b_08971_6.wav, 실제: 샤워할때물소리, 예측: 샤워할때물소리, 결과: OK
# 파일명: N-10_220919_A_3_b_09114_3.wav, 실제: 샤워할때물소리, 예측: 샤워할때물소리, 결과: OK
# 파일명: N-10_220920_A_3_b_09344_2.wav, 실제: 샤워할때물소리, 예측: 샤워할때물소리, 결과: OK
# 파일명: N-10_220917_A_3_b_08837_9.wav, 실제: 샤워할때물소리, 예측: 샤워할때물소리, 결과: OK
# 파일명: N-10_220919_A_3_b_09114_8.wav, 실제: 샤워할때물소리, 예측: 샤워할때물소리, 결과: OK
# 파일명: N-10_220919_A_3_b_09114_5.wav, 실제: 샤워할때물소리, 예측: 샤워할때물소리, 결과: OK
# 파일명: N-10_220904_A_3_b_08785_0.wav, 실제: 샤워할때물소리, 예측: 샤워할때물소리, 결과: OK
# 파일명: N-10_220919_A_3_b_08969_2.wav, 실제: 샤워할때물소리, 예측: 샤워할때물소리, 결과: OK
# 파일명: N-10_220915_A_2_b_04500_1.wav, 실제: 문여닫는소리, 예측: 문여닫는소리, 결과: OK
# 파일명: N-10_220925_A_2_b_05147_2.wav, 실제: 문여닫는소리, 예측: 문여닫는소리, 결과: OK
# 파일명: N-10_220921_A_2_b_05079_4.wav, 실제: 문여닫는소리, 예측: 강아지짓는소리, 결과: FAIL
# 파일명: N-10_220924_A_2_b_05034_0.wav, 실제: 문여닫는소리, 예측: 문여닫는소리, 결과: OK
# 파일명: N-10_220921_A_2_b_04837_3.wav, 실제: 문여닫는소리, 예측: 문여닫는소리, 결과: OK
# 파일명: N-10_220919_A_2_b_05133_3.wav, 실제: 문여닫는소리, 예측: 가구끄는소리, 결과: FAIL
# 파일명: N-10_220926_A_2_b_04580_2.wav, 실제: 문여닫는소리, 예측: 골프퍼팅(골굴리는소리), 결과: FAIL
# 파일명: N-10_220914_A_2_b_04395_5.wav, 실제: 문여닫는소리, 예측: 고양이우는소리, 결과: FAIL
# 파일명: N-10_220903_A_2_b_04420_4.wav, 실제: 문여닫는소리, 예측: 망치질소리, 결과: FAIL
# 파일명: N-10_220905_A_2_b_05062_0.wav, 실제: 문여닫는소리, 예측: 가구끄는소리, 결과: FAIL
# 파일명: N-10_220903_A_4_b_15372_3.wav, 실제: 피아노연주소리, 예측: 피아노연주소리, 결과: OK
# 파일명: N-10_220919_A_4_b_15802_0.wav, 실제: 피아노연주소리, 예측: 피아노연주소리, 결과: OK
# 파일명: N-10_220920_A_4_b_15825_0.wav, 실제: 피아노연주소리, 예측: 피아노연주소리, 결과: OK
# 파일명: N-10_220918_A_4_b_15796_0.wav, 실제: 피아노연주소리, 예측: 피아노연주소리, 결과: OK
# 파일명: N-10_220925_A_4_b_15564_3.wav, 실제: 피아노연주소리, 예측: 피아노연주소리, 결과: OK
# 파일명: N-10_220913_A_4_b_15386_2.wav, 실제: 피아노연주소리, 예측: 피아노연주소리, 결과: OK
# 파일명: N-10_220903_A_4_b_15107_1.wav, 실제: 피아노연주소리, 예측: 피아노연주소리, 결과: OK
# 파일명: N-10_220922_A_4_b_15857_3.wav, 실제: 피아노연주소리, 예측: 피아노연주소리, 결과: OK
# 파일명: N-10_220831_A_4_b_15333_1.wav, 실제: 피아노연주소리, 예측: 피아노연주소리, 결과: OK
# 파일명: N-10_220903_A_4_b_15122_0.wav, 실제: 피아노연주소리, 예측: 피아노연주소리, 결과: OK
# 파일명: N-10_220920_A_3_e_12794_0.wav, 실제: 진공청소기소리, 예측: 가구끄는소리, 결과: FAIL
# 파일명: N-10_220922_A_3_e_12660_0.wav, 실제: 진공청소기소리, 예측: 진공청소기소리, 결과: OK
# 파일명: N-10_220923_A_3_e_12226_3.wav, 실제: 진공청소기소리, 예측: 드럼세탁기소리, 결과: FAIL
# 파일명: N-10_220920_A_3_e_12422_2.wav, 실제: 진공청소기소리, 예측: 진공청소기소리, 결과: OK
# 파일명: N-10_220923_A_3_e_12440_2.wav, 실제: 진공청소기소리, 예측: 가구끄는소리, 결과: FAIL
# 파일명: N-10_220920_A_3_e_11902_1.wav, 실제: 진공청소기소리, 예측: 진공청소기소리, 결과: OK
# 파일명: N-10_220923_A_3_e_12225_0.wav, 실제: 진공청소기소리, 예측: 진공청소기소리, 결과: OK
# 파일명: N-10_220923_A_3_e_12226_4.wav, 실제: 진공청소기소리, 예측: 드럼세탁기소리, 결과: FAIL
# 파일명: N-10_220923_A_3_e_11928_4.wav, 실제: 진공청소기소리, 예측: 진공청소기소리, 결과: OK
# 파일명: N-10_220916_A_3_e_11754_1.wav, 실제: 진공청소기소리, 예측: 진공청소기소리, 결과: OK
# 파일명: N-10_220919_A_2_a_03921_0.wav, 실제: 가구끄는소리, 예측: 가구끄는소리, 결과: OK
# 파일명: N-10_220907_A_2_a_03434_4.wav, 실제: 가구끄는소리, 예측: 가구끄는소리, 결과: OK
# 파일명: N-10_220910_A_2_a_04241_3.wav, 실제: 가구끄는소리, 예측: 가구끄는소리, 결과: OK
# 파일명: N-10_220914_A_2_a_03628_3.wav, 실제: 가구끄는소리, 예측: 고양이우는소리, 결과: FAIL
# 파일명: N-10_220924_A_2_a_03862_4.wav, 실제: 가구끄는소리, 예측: 진공청소기소리, 결과: FAIL
# 파일명: N-10_220922_A_2_a_03978_3.wav, 실제: 가구끄는소리, 예측: 바이올린연주소리, 결과: FAIL
# 파일명: N-10_220919_A_2_a_03492_1.wav, 실제: 가구끄는소리, 예측: 가구끄는소리, 결과: OK
# 파일명: N-10_220914_A_2_a_03305_2.wav, 실제: 가구끄는소리, 예측: 가구끄는소리, 결과: OK
# 파일명: N-10_220915_A_2_a_04089_5.wav, 실제: 가구끄는소리, 예측: 가구끄는소리, 결과: OK
# 파일명: N-10_220919_A_2_a_04178_1.wav, 실제: 가구끄는소리, 예측: 가구끄는소리, 결과: OK
# 파일명: N-10_221001_A_3_d_11147_1.wav, 실제: 통돌이세탁기소리, 예측: 통돌이세탁기소리, 결과: OK
# 파일명: N-10_220920_A_3_d_11112_1.wav, 실제: 통돌이세탁기소리, 예측: 통돌이세탁기소리, 결과: OK
# 파일명: N-10_220930_A_3_d_11166_0.wav, 실제: 통돌이세탁기소리, 예측: 샤워할때물소리, 결과: FAIL
# 파일명: N-10_220922_A_3_d_10720_3.wav, 실제: 통돌이세탁기소리, 예측: 드럼세탁기소리, 결과: FAIL
# 파일명: N-10_220928_A_3_d_11033_2.wav, 실제: 통돌이세탁기소리, 예측: 통돌이세탁기소리, 결과: OK
# 파일명: N-10_220924_A_3_d_10874_3.wav, 실제: 통돌이세탁기소리, 예측: 통돌이세탁기소리, 결과: OK
# 파일명: N-10_220921_A_3_d_11063_2.wav, 실제: 통돌이세탁기소리, 예측: 샤워할때물소리, 결과: FAIL
# 파일명: N-10_220930_A_3_d_11166_1.wav, 실제: 통돌이세탁기소리, 예측: 통돌이세탁기소리, 결과: OK
# 파일명: N-10_220916_A_3_d_11097_1.wav, 실제: 통돌이세탁기소리, 예측: 통돌이세탁기소리, 결과: OK
# 파일명: N-10_220919_A_3_d_11707_3.wav, 실제: 통돌이세탁기소리, 예측: 샤워할때물소리, 결과: FAIL
# 파일명: N-10_220919_A_5_a_16622_1.wav, 실제: 강아지짓는소리, 예측: 강아지짓는소리, 결과: OK
# 파일명: N-10_221016_A_5_a_16313_0.wav, 실제: 강아지짓는소리, 예측: 강아지짓는소리, 결과: OK
# 파일명: N-10_221018_A_5_a_16368_0.wav, 실제: 강아지짓는소리, 예측: 강아지짓는소리, 결과: OK
# 파일명: N-10_221010_A_5_a_16969_8.wav, 실제: 강아지짓는소리, 예측: 강아지짓는소리, 결과: OK
# 파일명: N-10_221017_A_5_a_16514_1.wav, 실제: 강아지짓는소리, 예측: 강아지짓는소리, 결과: OK
# 파일명: N-10_221012_A_5_a_16248_0.wav, 실제: 강아지짓는소리, 예측: 강아지짓는소리, 결과: OK
# 파일명: N-10_221007_A_5_a_16184_0.wav, 실제: 강아지짓는소리, 예측: 강아지짓는소리, 결과: OK
# 파일명: N-10_220916_A_5_a_16585_3.wav, 실제: 강아지짓는소리, 예측: 강아지짓는소리, 결과: OK
# 파일명: N-10_220928_A_5_a_16745_8.wav, 실제: 강아지짓는소리, 예측: 강아지짓는소리, 결과: OK
# 파일명: N-10_221008_A_5_a_16419_3.wav, 실제: 강아지짓는소리, 예측: 강아지짓는소리, 결과: OK
# ------------------------------
# 총 파일 수: 170개, 올바른 예측: 142개
# F1 Score: 0.8268
